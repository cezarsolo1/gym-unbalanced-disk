# %%
import gymnasium as gym
import gym_unbalanced_disk, time
import gymnasium.wrappers
import torch
import numpy as np

from torch import nn
from copy import deepcopy
from matplotlib import pyplot as plt

if not hasattr(gym_unbalanced_disk.UnbalancedDisk, '_old_reset'):
    gym_unbalanced_disk.UnbalancedDisk._old_reset = gym_unbalanced_disk.UnbalancedDisk.reset

def patched_reset(self, seed=None, options=None):
    # Call the original reset without the new keyword parameters
    return self._old_reset()

gym_unbalanced_disk.UnbalancedDisk.reset = patched_reset

raw_env = gym_unbalanced_disk.UnbalancedDisk(dt=0.025, umax=3.) 
env = gym.wrappers.TimeLimit(raw_env, max_episode_steps=200)


#env = gym_unbalanced_disk.UnbalancedDisk(dt=0.025, umax=3.) #alternative

obs, info = env.reset()
try:
    for i in range(200):
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample()) #random action
        print(obs, reward)
        env.render()
        time.sleep(1/24)
        if terminated or truncated:
            obs = env.reset()
finally: #this will always run
    env.close()
# Out:
# [0.01460364 0.8811672 ] 2.772582904800131e-11
# [ 0.00567249 -1.23676557] 2.5417567487032383e-11
# [0.00297264 0.82914738] 2.386659482583203e-11
# [0.02297785 0.79763878] 3.280947520306552e-11
# [0.060657   2.12553576] 5.789829870272044e-11
# [0.09408833 0.54124618] 9.628643720867509e-11
# [ 0.08956467 -0.72167604] 9.181204975633419e-11
# [ 0.0808751  -0.06146208] 7.915957099828178e-11
# [ 0.07921356 -0.06979136] 7.720991459914555e-11
# [ 0.0671462  -0.82439327] 6.498754793858827e-11
# [ 0.03510385 -1.68510406] 4.0006753342850853e-11
# [-0.02641847 -3.23312197] 3.429776947998764e-11
# [-0.10361764 -2.84042462] 1.1020213864668166e-10
# [-0.16860434 -2.34946381] 2.9195090828691364e-10
# [-0.19812492 -0.17161239] 4.641904913213995e-10
# [-0.18219455  1.52457576] 3.5980980917545494e-10
# [-0.15252244  0.70348071] 2.380472279315111e-10
# [-0.10873229  2.82994181] 1.2225074628516392e-10
# [-0.04008171  2.6780724 ] 4.2572912934384676e-11
# [0.02496935 2.40410778] 3.31961690667461e-11
# [0.08030011 2.09233594] 7.906610481629621e-11
# [0.14239109 2.90502893] 2.0379547041664673e-10
# [0.20246936 1.82405783] 4.892549947297907e-10
# [0.23942156 1.16429367] 8.433293312410795e-10
# [0.26404849 0.76625974] 1.1942375977620708e-09
# [ 0.27380277 -0.03447955] 1.3495400720861344e-09
# [ 0.23843517 -2.69506108] 8.228480866328234e-10
# [ 0.15991064 -3.63804684] 2.5671667475942366e-10
# [ 0.06385419 -3.80340877] 6.278222933704935e-11
# [-0.0284771  -3.75325729] 3.634007156746617e-11
# [-0.10695359 -2.2746339 ] 1.1547763124220029e-10
# [-0.13613211 -0.15091738] 1.8209085563730957e-10
# [-0.12869682  0.65387255] 1.6463057466943586e-10
# [-0.12144847 -0.09384924] 1.4955806552558745e-10
# [-0.13234971 -0.61114421] 1.708698962353148e-10
# [-0.15195609 -1.09453959] 2.3528240954392014e-10
# [-0.17641414 -0.78943761] 3.3374743489019975e-10
# [-0.17679544  0.70487091] 3.3397548471170984e-10
# [-0.17339372 -0.30880562] 3.153430987331343e-10
# [-0.15305261  1.83448791] 2.357127436853629e-10
# [-0.08251546  3.9578361 ] 7.870858944897377e-11
# [0.02273464 4.16256091] 3.224199949375282e-11
# [0.11122838 2.89367782] 1.2496094527586577e-10
# [0.15704541 0.81548255] 2.503974075022863e-10
# [ 0.15980382 -0.57292038] 2.579383919210834e-10
# [ 0.1365114 -1.2614288] 1.8289228301869008e-10
# [ 0.09904074 -1.68363274] 1.0479000424583411e-10
# [ 0.07537546 -0.26325026] 7.238617016880879e-11
# [ 0.07203654 -0.00290155] 6.882245484328304e-11
# [0.09195045 1.66316664] 9.469165678252543e-11
# [ 0.10484208 -0.68117616] 1.1209678145045266e-10
# [ 0.08719104 -0.66346841] 8.679174368170704e-11
# [0.08670922 0.57096907] 8.652130114996745e-11
# [0.1199232  2.12997107] 1.4458073451398731e-10
# [0.17710861 2.25829443] 3.2836300737305807e-10
# [ 0.20109988 -0.25801207] 4.71364846801504e-10
# [ 0.16898704 -2.21212233] 2.979180642306487e-10
# [ 0.11539125 -2.09062709] 1.3304778268750188e-10
# [ 0.06798626 -1.60924923] 6.576964934352495e-11
# [ 0.03074924 -1.4566177 ] 3.6371332029947705e-11
# [0.01978897 0.39166053] 2.9883071547248134e-11
# [0.02294061 0.07740538] 3.2744094249840843e-11
# [ 0.00703023 -1.48496215] 2.4785299421607696e-11
# [-0.00614969  0.45018239] 2.5577582945146307e-11
# [-0.00423929 -0.16966587] 2.4575647724544894e-11
# [-0.02251451 -1.35607365] 3.3159052149741185e-11
# [-0.03072728  0.83394645] 3.608316535349811e-11
# [-0.02754602 -0.64961584] 3.536658152607092e-11
# [-0.03762062 -0.04582044] 4.046211551822113e-11
# [-0.05181204 -1.07023189] 5.03014452365092e-11
# [-0.05700929  0.50310605] 5.5182558666276e-11
# [-0.04535757  0.56387992] 4.4904930916657377e-11
# [-0.01457539  1.75234155] 2.8591469423736927e-11
# [0.03461916 2.18078729] 3.956040869938074e-11
# [0.11178417 3.7861105 ] 1.2437632532630226e-10
# [0.17075393 1.02007811] 3.0526604720578e-10
# [0.20933845 1.99126816] 5.323993367949348e-10
# [ 0.23210153 -0.02367529] 7.597384735671764e-10
# [ 0.22724921 -0.48163476] 6.927279654631848e-10
# [ 0.21247549 -0.83229746] 5.449697772636695e-10
# [ 0.17900872 -1.60458012] 3.4777288236263937e-10
# [ 0.15294421 -0.54047349] 2.335916877264433e-10
# [0.14714818 0.09076636] 2.170357806295984e-10
# [0.16268804 1.24736672] 2.789360101654665e-10
# [ 0.17940347 -0.04218452] 3.4624418950835697e-10
# [ 0.15741173 -1.69076056] 2.5059904230111897e-10
# [ 0.12080306 -1.27829429] 1.4367757646513277e-10
# [ 0.08540839 -1.39280401] 8.652790912045965e-11
# [ 0.04448764 -1.94795284] 4.5524462496605104e-11
# [-0.00335366 -1.89881125] 2.437166194861066e-11
# [-0.04846438 -1.74737844] 4.954983989515487e-11
# [-0.10662267 -2.78025993] 1.1799350312252554e-10
# [-0.18321176 -3.41149697] 3.76113109230988e-10
# [-0.26624446 -2.94242209] 1.1962166049204082e-09
# [-0.33969483 -2.9260927 ] 3.386263386264263e-09
# [-0.41500471 -3.1337743 ] 9.643672269524181e-09
# [-0.45008277  0.2703999 ] 1.550955803022738e-08
# [-0.41276921  2.60496569] 9.513455321879473e-09
# [-0.33071478  3.87475477] 3.0981499645875866e-09
# [-0.22908094  4.42552541] 7.021452313859911e-10
# [-0.10288202  5.59239488] 1.0878599832561363e-10
# [0.03481082 5.2254088 ] 3.913966681743196e-11
# [0.13761642 2.86072637] 1.8275422203169274e-10
# [0.21416238 3.27528566] 5.699444746507609e-10
# [0.29863909 3.51848121] 1.9401350981093492e-09
# [0.38099482 3.02213498] 6.0906281641925486e-09
# [0.45439445 2.7447506 ] 1.6237400932167418e-08
# [ 0.48194665 -0.48809545] 2.347456125431499e-08
# [ 0.43249321 -3.32932433] 1.2347783913392122e-08
# [ 0.32299285 -5.3349906 ] 2.7633312338079637e-09
# [ 0.1867478  -5.68292663] 3.787953486779513e-10
# [ 0.0648268  -3.94370894] 6.182008636800553e-11
# [-0.04990325 -5.18137743] 5.008255173350555e-11
# [-0.16297194 -3.7465845 ] 2.7173711795158407e-10
# [-0.24519501 -2.74398777] 8.935873417311481e-10
# [-0.31356399 -2.59779118] 2.323902961617297e-09
# [-0.3491078  -0.30573665] 3.861088650333826e-09
# [-0.36007483 -0.64269766] 4.555600190271746e-09
# [-0.37360037 -0.44654189] 5.503682557781865e-09
# [-0.37832047 -0.08164505] 6.029595790204728e-09
# [-0.36452104  1.39523147] 4.790024605703663e-09
# [-0.31961453  1.9647199 ] 2.6609947381919453e-09
# [-0.23751032  4.68255666] 8.086720873774879e-10
# [-0.11663246  4.92879678] 1.3633404441468975e-10
# [0.01664635 5.61496181] 2.945351184509475e-11
# [0.12776941 3.35825818] 1.6413366381167646e-10
# [0.20149397 2.64269867] 5.003757583688198e-10
# [0.2744752  3.08978632] 1.414599263127128e-09
# [0.35578691 3.22397642] 4.311081701022384e-09
# [0.40289443 0.59465448] 8.309870836580486e-09
# [ 0.41034443 -0.06124054] 9.02729053347539e-09
# [ 0.3719639  -2.89555852] 5.416772931231722e-09
# [ 0.30080182 -2.70332502] 2.0313780863345568e-09
# [ 0.24072204 -2.28939685] 8.297747427891744e-10
# [ 0.16353656 -3.79936758] 2.7072569902027067e-10
# [ 0.0489486  -5.24883211] 4.859975688075601e-11
# [-0.0792826  -4.78380711] 7.563368021182543e-11
# [-0.19322386 -4.32260537] 4.181660615926296e-10
# [-0.26447899 -1.55034059] 1.2139114884482872e-09
# [-0.30919929 -1.85607045] 2.2280283558927827e-09
# [-0.36190001 -2.22990979] 4.562271630748691e-09
# [-0.413876   -2.03892522] 9.509776282332418e-09
# [-0.41981172  1.28134605] 1.0640571740006302e-08
# [-0.37977535  2.02166895] 6.042519615978669e-09
# [-0.31497976  3.15926702] 2.444634747283966e-09
# [-0.23432418  3.39682174] 7.554862032846766e-10
# [-0.16953415  1.71514096] 2.9596125514102715e-10
# [-0.14860308 -0.03303591] 2.170860536683479e-10
# [-0.1405308   0.48214215] 1.9908641929454887e-10
# [-0.14964511 -1.05434538] 2.2401106891680117e-10
# [-0.19229377 -2.29860015] 4.17754534338854e-10
# [-0.24381649 -1.76073827] 8.766423324316842e-10
# [-0.26766218 -0.06871345] 1.2176405067904068e-09
# [-0.2448737   1.70075195] 9.047406717674429e-10
# [-0.18020017  3.45386119] 3.518629675892856e-10
# [-0.0861899   4.01204872] 8.642457879671932e-11
# [1.67991138e-03 3.12243600e+00] 2.4138067826461737e-11
# [0.09515798 4.05598918] 9.668977769246246e-11
# [0.19986179 4.36659485] 4.675131242822413e-10
# [0.30989156 4.39261751] 2.268481510431423e-09
# [0.3945879  2.34187742] 7.316764555460657e-09
# [0.4284904  0.26616612] 1.1391757152619668e-08
# [ 0.39411773 -2.81763534] 7.331038794440875e-09
# [ 0.31240683 -3.69900927] 2.3552978914235243e-09
# [ 0.20105691 -4.98211188] 4.925421386982086e-10
# [ 0.10030058 -3.23284667] 1.0634914195292314e-10
# [ 0.03025227 -2.19353829] 3.7523924115413726e-11
# [-0.03159976 -2.86370032] 3.753784278851249e-11
# [-0.10438488 -2.7653522 ] 1.1068363422741362e-10
# [-0.15896477 -1.83965753] 2.6297019962385754e-10
# [-0.17877775  0.38357001] 3.4156311328866265e-10
# [-0.16510859  0.73329348] 2.776039447475228e-10
# [-0.1419881  1.0475517] 1.9900013359552266e-10
# [-0.13370534 -0.38057488] 1.7860756251024134e-10
# [-0.12216372  1.34982744] 1.4747236371927538e-10
# [-0.06716015  2.86621695] 6.596889797966577e-11
# [-0.01527146  1.37238802] 2.906646142331401e-11
# [-0.00251156 -0.15205918] 2.3035414812716462e-11
# [-0.02286845 -1.61012875] 3.256473770726071e-11
# [-0.08535882 -3.31695333] 8.43806445895457e-11
# [-0.1800419  -4.27335925] 3.5188531850109196e-10
# [-0.28624407 -4.28729467] 1.6660418347470324e-09
# [-0.38253212 -3.14359251] 6.123333865292164e-09
# [-0.45784245 -2.86204266] 1.6995151483659148e-08
# [-0.48293514  0.69313981] 2.4002778267418302e-08
# [-0.43080466  3.54900928] 1.1761483370625755e-08
# [-0.33462101  4.1220633 ] 3.133911840212522e-09
# [-0.19622488  6.71826141] 4.4574069968472204e-10
# [-5.86838266e-03  8.55876182e+00] 2.4424870474772014e-11
# [0.22058379 9.38936311] 6.438433958467252e-10
# [0.44484972 8.21488613] 1.4113944030853476e-08
# [0.64383175 7.6775931 ] 1.8577914055676155e-07
# [0.79822223 4.73860935] 1.2085100176006372e-06
# [0.87671026 1.48866122] 2.949094472178058e-06
# [ 0.89281353 -0.16482301] 3.5282888872824615e-06
# [ 0.84000079 -3.99269334] 1.9510550168128523e-06
# [ 0.72210635 -5.35130901] 4.928507218026921e-07
# [ 0.55779765 -7.66261901] 6.457699453070844e-08
# [ 0.34789911 -9.14181939] 3.841903508800063e-09
# [  0.09925509 -10.56113121] 1.0572340718745644e-10

# %%
class Qfunction(nn.Module):
    def __init__(self, env):
        super(Qfunction,self).__init__()
        self.lay1 = nn.Linear(env.observation_space.shape[0], 128) #a)
        self.F1 =  nn.Tanh() #a)
        self.lay2 = nn.Linear(128, num_actions) #a)
    
    def forward(self, obs):
        return self.lay2(self.F1(self.lay1(obs))) #a)

max_episode_steps = 500
env = gym.make('unbalanced-disk-sincos-v0', dt=0.025, umax=3.) 
env = gym.wrappers.TimeLimit(env,max_episode_steps=max_episode_steps) 

#def reward_fun(self):
#    cos_th = np.cos(self.th)
#    angle_reward = 0.5 * (1.0 - cos_th)
#    top_bonus = np.exp(-(1.0 + cos_th)**2 / 0.1)
#    return angle_reward + top_bonus

#env.unwrapped.reward_fun = reward_fun

def make_env():
    env = gym.make('unbalanced-disk-sincos-v0')
    env.unwrapped.reward_fun = lambda self: 0.5 * (1.0 - np.cos(self.th))**2
    return env

env = make_env()

# Definition of discrete actions
discrete_actions = np.array([
    -3.0, -2.0, -1.0, -0.5, -0.25,
    -0.1, -0.05, -0.02,
     0.0,
     0.02, 0.05, 0.1,
     0.25, 0.5, 1.0, 2.0, 3.0
])
num_actions = len(discrete_actions)

Q = Qfunction(env)
#test validity:
obs, info = env.reset()
obs_tensor = torch.tensor(obs,dtype=torch.float32)[None,:] #convert to an torch tensor with size (1, Nobs=6)
print('obs_tensor = ', obs_tensor)
print('Q(x) = ',Q(obs_tensor)) #output #(1,Naction=3)
# Out:
# obs_tensor =  tensor([[-5.7885e-04,  1.0000e+00,  1.0756e-03]])
# Q(x) =  tensor([[-0.0481,  0.1564, -0.2880, -0.1327, -0.0588, -0.3482,  0.0522,  0.0750,
#          -0.1377,  0.0545,  0.3221,  0.1840, -0.0318,  0.2957,  0.0129, -0.4346,
#           0.1806]], grad_fn=<AddmmBackward0>)
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %%
#visualize
def show(Q,env):
    with torch.no_grad():
        #you can use Qfun(obs) as a shorthand for the q function.
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() #convert x to torch.tensor -> put in the Q function -> back to numpy
        try:
            obs, info = env.reset() #b)
            env.render() #b)
            time.sleep(1) #b)
            while True: #b)
                action = np.argmax(Qfun(obs)) #b)
                voltage_action = float(discrete_actions[action])
                obs, reward, terminated, truncated, info = env.step(voltage_action) #b)
                time.sleep(1/60) #b)
                env.render() #b)
                if terminated or truncated: #b)
                    time.sleep(0.5)  #b)
                    break  #b)
        finally: #this will always run even when an error occurs
            env.close()
 
Q = Qfunction(env)
#show(Q,env)

# %%
def rollout(Q, env, epsilon=0.1, N_rollout=10_000): 
    # Save the following arrays (using .append)
    Start_state = [] # hold an array of (x_t)
    Actions = []     # hold an array of (u_t)
    Rewards = []     # hold an array of (r_{t+1})
    End_state = []   # hold an array of (x_{t+1})
    Terminal = []    # hold an array of (terminal_{t+1})
    
    # Qfun(a numpy array of the obs) -> a numpy array of Q values
    Qfun = lambda x: Q(torch.tensor(x[None, :], dtype=torch.float32))[0].numpy() 
    
    with torch.no_grad():
        obs, info = env.reset()
        obs = obs + np.array([
            np.random.normal(0, 0.01),
            np.random.normal(0, 0.01),
            np.random.normal(0, 0.05)
            ])
        obs = np.array(obs, dtype=np.float32) 
        
        for i in range(N_rollout): 
            if np.random.uniform() > epsilon: 
                Qnow = Qfun(obs) 
                action = np.argmax(Qnow) 
            else: 
                action = np.random.randint(0, num_actions) 
                
            Start_state.append(obs) 
            Actions.append(action) 

            # FIX: Get the raw scalar float number out of the array mapping
            voltage_action = float(discrete_actions[action])
            
            # Pass the raw scalar value directly to the step function
            obs_next, reward, terminated, truncated, info = env.step(voltage_action) 
            obs_next = obs_next + np.array([
                np.random.normal(0, 0.01),
                np.random.normal(0, 0.01),
                np.random.normal(0, 0.05)
                ])
            obs_next = np.array(obs_next, dtype=np.float32) 

            Terminal.append(terminated) 
            Rewards.append(reward) 
            End_state.append(obs_next) 

            if terminated or truncated: 
                obs, info = env.reset() 
                obs = obs + np.array([
                    np.random.normal(0, 0.01),
                    np.random.normal(0, 0.01),
                    np.random.normal(0, 0.05)
                    ])
                obs = np.array(obs, dtype=np.float32) 
            else: 
                obs = obs_next 
                
    assert len(Start_state) == len(Actions) == len(Rewards) == len(End_state) == len(Terminal), \
        f'error in lengths: {len(Start_state)}=={len(Actions)}=={len(Rewards)}=={len(End_state)}=={len(Terminal)}'
        
    return np.array(Start_state), np.array(Actions), np.array(Rewards), np.array(End_state), np.array(Terminal).astype(int)

# Trigger and test
Q = Qfunction(env) 
Start_state, Actions, Rewards, End_state, Terminal = rollout(Q, env, N_rollout=300)
print("Data collected successfully! Shapes:")
print(f"States: {Start_state.shape}, Actions: {Actions.shape}, Rewards: {Rewards.shape}")
# Out:
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Data collected successfully! Shapes:
# States: (300, 3), Actions: (300,), Rewards: (300,)

# %%
def eval_Q(Q,env):
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy()
        rewards_acc = 0 #d)
        obs, info = env.reset() #d)
        while True: #d)
            action = np.argmax(Qfun(obs)) #d)
            voltage_action = float(discrete_actions[action])
            obs, reward, terminated, truncated, info = env.step(voltage_action) #d)
            rewards_acc += reward #d)
            if terminated or truncated: #d)
                return rewards_acc #d)

Q = Qfunction(env) 
plt.plot([eval_Q(Q,env) for i in range(100)],'.') #d)
plt.show() #d)

# %%
def DQN_rollout(Q, optimizer, env, gamma=0.98, use_target_net=False, N_iterations=21, N_rollout=20000, \
                N_epochs=10, batch_size=32, N_evals=10, target_net_update_feq=100):
    best = -float('inf')
    torch.save(Q.state_dict(),'Q-checkpoint')
    try:
        for iteration in range(N_iterations):
            epsilon = max(0.05, 1.0 - iteration/(N_iterations*1.5))
            print(f'rollout iteration {iteration} with epsilon={epsilon:.2%}...')
            
            #2. rollout
            Start_state, Actions, Rewards, End_state, Terminal = rollout(Q, env, epsilon=epsilon, N_rollout=N_rollout) #e) 2.
            
            #Data conversion, no changes required
            convert = lambda x: [torch.tensor(xi,dtype=torch.float32) for xi in x]
            Start_state, Rewards, End_state, Terminal = convert([Start_state, Rewards, End_state, Terminal])
            Actions = Actions.astype(int)

            # Shuffle rollout data before batching
            perm = torch.randperm(len(Start_state))
            Start_state = Start_state[perm]
            Actions      = Actions[perm]
            Rewards      = Rewards[perm]
            End_state    = End_state[perm]
            Terminal     = Terminal[perm]

            print('starting training on rollout information...')
            t = 0
            for epoch in range(N_epochs): 
                for i in range(batch_size,len(Start_state)+1,batch_size): 
                    if t%target_net_update_feq==0:
                        Qtarget = deepcopy(Q) #g)
                        pass
                    t += 1
                    
                    Start_state_batch, Actions_batch, Rewards_batch, End_state_batch, Terminal_batch = [d[i-batch_size:i] for d in \
                                                                                                        [Start_state, Actions, Rewards, End_state, Terminal]] #e=) 3.
                    
                    with torch.no_grad(): #3.
                        if use_target_net:
                            pass
                            maxQ = torch.max(Qtarget(End_state_batch),dim=1)[0] #g)
                        else:
                            maxQ = torch.max(Q(End_state_batch),dim=1)[0] #e=) 3.
                    
                    # action_index = np.stack((np.arange(batch_size),Actions_batch),axis=0)
                    # ids = np.arange(batch_size)
                    
                    Qnow = Q(Start_state_batch)
                    # print(f'{action_index.shape=}')
                    # print(f'{Qnow.shape=}')
                    Qnow = Qnow[np.arange(batch_size), Actions_batch] #Q(x_t,u_t) is given
                    # print(Rewards_batch.shape, maxQ.shape, Terminal_batch.shape, Qnow.shape)
                    Loss = torch.mean((Rewards_batch + gamma*maxQ*(1-Terminal_batch) - Qnow)**2) #e) 3.
                    optimizer.zero_grad() #e) 3.
                    Loss.backward() #e) 3.
                    optimizer.step() #e) 3.
                
            score = np.mean([eval_Q(Q,env) for i in range(N_evals)])
            print(f'iteration={iteration} Average Reward per episode: {score:.2f}')
            if score > best:
                best = score
                print('################################# \n new best',best,'saving Q... \n#################################')
                torch.save(Q.state_dict(),'Q-checkpoint')
            
            print('loading best result')
            Q.load_state_dict(torch.load('Q-checkpoint'))
    finally: #this will always run even when using the a KeyBoard Interrupt. 
        print('loading best result')
        Q.load_state_dict(torch.load('Q-checkpoint'))

# %%
gamma = 0.999 #f=)
batch_size = 64 #f=)
N_iterations = 100 #f=)
N_rollout = 20000 #f=)
N_epochs = 6 #f=)
N_evals = 5 #f=)
lr = 0.005 #given
target_net_update_feq = 200

Q = Qfunction(env)
optimizer = torch.optim.Adam(Q.parameters(),lr=lr) #low learning rate
DQN_rollout(Q, optimizer, env, use_target_net=True, gamma=gamma, N_iterations=N_iterations, \
            N_rollout=N_rollout, N_epochs=N_epochs, N_evals=N_evals, batch_size=batch_size, \
            target_net_update_feq=target_net_update_feq)
# Out:
# rollout iteration 0 with epsilon=100.00%...
# starting training on rollout information...
# iteration=0 Average Reward per episode: 233.47
# #################################
#  new best 233.4708395862752 saving Q...
# #################################
# loading best result
# rollout iteration 1 with epsilon=99.33%...
# starting training on rollout information...
# iteration=1 Average Reward per episode: 17.60
# loading best result
# rollout iteration 2 with epsilon=98.67%...
# starting training on rollout information...
# iteration=2 Average Reward per episode: 11.38
# loading best result
# rollout iteration 3 with epsilon=98.00%...
# starting training on rollout information...
# iteration=3 Average Reward per episode: 3.44
# loading best result
# rollout iteration 4 with epsilon=97.33%...
# starting training on rollout information...
# iteration=4 Average Reward per episode: 8.43
# loading best result
# rollout iteration 5 with epsilon=96.67%...
# starting training on rollout information...
# iteration=5 Average Reward per episode: 8.83
# loading best result
# rollout iteration 6 with epsilon=96.00%...
# starting training on rollout information...
# iteration=6 Average Reward per episode: 11.38
# loading best result
# rollout iteration 7 with epsilon=95.33%...
# starting training on rollout information...
# iteration=7 Average Reward per episode: 11.39
# loading best result
# rollout iteration 8 with epsilon=94.67%...
# starting training on rollout information...
# iteration=8 Average Reward per episode: 13.65
# loading best result
# rollout iteration 9 with epsilon=94.00%...
# starting training on rollout information...
# iteration=9 Average Reward per episode: 21.88
# loading best result
# rollout iteration 10 with epsilon=93.33%...
# starting training on rollout information...
# iteration=10 Average Reward per episode: 1.37
# loading best result
# rollout iteration 11 with epsilon=92.67%...
# starting training on rollout information...
# iteration=11 Average Reward per episode: 8.97
# loading best result
# rollout iteration 12 with epsilon=92.00%...
# starting training on rollout information...
# iteration=12 Average Reward per episode: 0.00
# loading best result
# rollout iteration 13 with epsilon=91.33%...
# starting training on rollout information...
# iteration=13 Average Reward per episode: 11.39
# loading best result
# rollout iteration 14 with epsilon=90.67%...
# starting training on rollout information...
# iteration=14 Average Reward per episode: 11.38
# loading best result
# rollout iteration 15 with epsilon=90.00%...
# starting training on rollout information...
# iteration=15 Average Reward per episode: 6.64
# loading best result
# rollout iteration 16 with epsilon=89.33%...
# starting training on rollout information...
# iteration=16 Average Reward per episode: 11.64
# loading best result
# rollout iteration 17 with epsilon=88.67%...
# starting training on rollout information...
# iteration=17 Average Reward per episode: 263.93
# #################################
#  new best 263.93228474318124 saving Q...
# #################################
# loading best result
# rollout iteration 18 with epsilon=88.00%...
# starting training on rollout information...
# iteration=18 Average Reward per episode: 218.24
# loading best result
# rollout iteration 19 with epsilon=87.33%...
# starting training on rollout information...
# iteration=19 Average Reward per episode: 0.00
# loading best result
# rollout iteration 20 with epsilon=86.67%...
# starting training on rollout information...
# iteration=20 Average Reward per episode: 221.18
# loading best result
# rollout iteration 21 with epsilon=86.00%...
# starting training on rollout information...
# iteration=21 Average Reward per episode: 250.80
# loading best result
# rollout iteration 22 with epsilon=85.33%...
# starting training on rollout information...
# iteration=22 Average Reward per episode: 230.35
# loading best result
# rollout iteration 23 with epsilon=84.67%...
# starting training on rollout information...
# iteration=23 Average Reward per episode: 224.24
# loading best result
# rollout iteration 24 with epsilon=84.00%...
# starting training on rollout information...
# iteration=24 Average Reward per episode: 0.00
# loading best result
# rollout iteration 25 with epsilon=83.33%...
# starting training on rollout information...
# iteration=25 Average Reward per episode: 0.00
# loading best result
# rollout iteration 26 with epsilon=82.67%...
# starting training on rollout information...
# iteration=26 Average Reward per episode: 0.00
# loading best result
# rollout iteration 27 with epsilon=82.00%...
# starting training on rollout information...
# iteration=27 Average Reward per episode: 239.17
# loading best result
# rollout iteration 28 with epsilon=81.33%...
# starting training on rollout information...
# iteration=28 Average Reward per episode: 263.96
# #################################
#  new best 263.9575517828045 saving Q...
# #################################
# loading best result
# rollout iteration 29 with epsilon=80.67%...
# starting training on rollout information...
# iteration=29 Average Reward per episode: 230.94
# loading best result
# rollout iteration 30 with epsilon=80.00%...
# starting training on rollout information...
# iteration=30 Average Reward per episode: 231.67
# loading best result
# rollout iteration 31 with epsilon=79.33%...
# starting training on rollout information...
# iteration=31 Average Reward per episode: 230.88
# loading best result
# rollout iteration 32 with epsilon=78.67%...
# starting training on rollout information...
# iteration=32 Average Reward per episode: 234.45
# loading best result
# rollout iteration 33 with epsilon=78.00%...
# starting training on rollout information...
# iteration=33 Average Reward per episode: 227.19
# loading best result
# rollout iteration 34 with epsilon=77.33%...
# starting training on rollout information...
# iteration=34 Average Reward per episode: 231.78
# loading best result
# rollout iteration 35 with epsilon=76.67%...
# starting training on rollout information...
# iteration=35 Average Reward per episode: 227.82
# loading best result
# rollout iteration 36 with epsilon=76.00%...
# starting training on rollout information...
# iteration=36 Average Reward per episode: 226.92
# loading best result
# rollout iteration 37 with epsilon=75.33%...
# starting training on rollout information...
# iteration=37 Average Reward per episode: 224.20
# loading best result
# rollout iteration 38 with epsilon=74.67%...
# starting training on rollout information...
# iteration=38 Average Reward per episode: 0.11
# loading best result
# rollout iteration 39 with epsilon=74.00%...
# starting training on rollout information...
# iteration=39 Average Reward per episode: 229.44
# loading best result
# rollout iteration 40 with epsilon=73.33%...
# starting training on rollout information...
# iteration=40 Average Reward per episode: 0.00
# loading best result
# rollout iteration 41 with epsilon=72.67%...
# starting training on rollout information...
# iteration=41 Average Reward per episode: 231.04
# loading best result
# rollout iteration 42 with epsilon=72.00%...
# starting training on rollout information...
# iteration=42 Average Reward per episode: 229.79
# loading best result
# rollout iteration 43 with epsilon=71.33%...
# starting training on rollout information...
# iteration=43 Average Reward per episode: 228.70
# loading best result
# rollout iteration 44 with epsilon=70.67%...
# starting training on rollout information...
# iteration=44 Average Reward per episode: 229.91
# loading best result
# rollout iteration 45 with epsilon=70.00%...
# starting training on rollout information...
# iteration=45 Average Reward per episode: 226.21
# loading best result
# rollout iteration 46 with epsilon=69.33%...
# starting training on rollout information...
# iteration=46 Average Reward per episode: 231.64
# loading best result
# rollout iteration 47 with epsilon=68.67%...
# starting training on rollout information...
# iteration=47 Average Reward per episode: 232.32
# loading best result
# rollout iteration 48 with epsilon=68.00%...
# starting training on rollout information...
# iteration=48 Average Reward per episode: 0.00
# loading best result
# rollout iteration 49 with epsilon=67.33%...
# starting training on rollout information...
# iteration=49 Average Reward per episode: 228.53
# loading best result
# rollout iteration 50 with epsilon=66.67%...
# starting training on rollout information...
# iteration=50 Average Reward per episode: 234.41
# loading best result
# rollout iteration 51 with epsilon=66.00%...
# starting training on rollout information...
# iteration=51 Average Reward per episode: 0.00
# loading best result
# rollout iteration 52 with epsilon=65.33%...
# starting training on rollout information...
# iteration=52 Average Reward per episode: 239.17
# loading best result
# rollout iteration 53 with epsilon=64.67%...
# starting training on rollout information...
# iteration=53 Average Reward per episode: 0.11
# loading best result
# rollout iteration 54 with epsilon=64.00%...
# starting training on rollout information...
# iteration=54 Average Reward per episode: 0.00
# loading best result
# rollout iteration 55 with epsilon=63.33%...
# starting training on rollout information...
# iteration=55 Average Reward per episode: 228.70
# loading best result
# rollout iteration 56 with epsilon=62.67%...
# starting training on rollout information...
# iteration=56 Average Reward per episode: 228.58
# loading best result
# rollout iteration 57 with epsilon=62.00%...
# starting training on rollout information...
# iteration=57 Average Reward per episode: 229.07
# loading best result
# rollout iteration 58 with epsilon=61.33%...
# starting training on rollout information...
# iteration=58 Average Reward per episode: 0.11
# loading best result
# rollout iteration 59 with epsilon=60.67%...
# starting training on rollout information...
# iteration=59 Average Reward per episode: 226.32
# loading best result
# rollout iteration 60 with epsilon=60.00%...
# starting training on rollout information...
# iteration=60 Average Reward per episode: 0.00
# loading best result
# rollout iteration 61 with epsilon=59.33%...
# starting training on rollout information...
# iteration=61 Average Reward per episode: 0.00
# loading best result
# rollout iteration 62 with epsilon=58.67%...
# starting training on rollout information...
# iteration=62 Average Reward per episode: 226.62
# loading best result
# rollout iteration 63 with epsilon=58.00%...
# starting training on rollout information...
# iteration=63 Average Reward per episode: 237.69
# loading best result
# rollout iteration 64 with epsilon=57.33%...
# starting training on rollout information...
# iteration=64 Average Reward per episode: 0.00
# loading best result
# rollout iteration 65 with epsilon=56.67%...
# starting training on rollout information...
# iteration=65 Average Reward per episode: 226.41
# loading best result
# rollout iteration 66 with epsilon=56.00%...
# starting training on rollout information...
# iteration=66 Average Reward per episode: 232.63
# loading best result
# rollout iteration 67 with epsilon=55.33%...
# starting training on rollout information...
# iteration=67 Average Reward per episode: 233.90
# loading best result
# rollout iteration 68 with epsilon=54.67%...
# starting training on rollout information...
# iteration=68 Average Reward per episode: 540.94
# #################################
#  new best 540.938468633998 saving Q...
# #################################
# loading best result
# rollout iteration 69 with epsilon=54.00%...
# starting training on rollout information...
# iteration=69 Average Reward per episode: 556.77
# #################################
#  new best 556.7746839747848 saving Q...
# #################################
# loading best result
# rollout iteration 70 with epsilon=53.33%...
# starting training on rollout information...
# iteration=70 Average Reward per episode: 558.84
# #################################
#  new best 558.836605599706 saving Q...
# #################################
# loading best result
# rollout iteration 71 with epsilon=52.67%...
# starting training on rollout information...
# iteration=71 Average Reward per episode: 536.69
# loading best result
# rollout iteration 72 with epsilon=52.00%...
# starting training on rollout information...
# iteration=72 Average Reward per episode: 538.25
# loading best result
# rollout iteration 73 with epsilon=51.33%...
# starting training on rollout information...
# iteration=73 Average Reward per episode: 528.43
# loading best result
# rollout iteration 74 with epsilon=50.67%...
# starting training on rollout information...
# iteration=74 Average Reward per episode: 463.61
# loading best result
# rollout iteration 75 with epsilon=50.00%...
# starting training on rollout information...
# iteration=75 Average Reward per episode: 539.73
# loading best result
# rollout iteration 76 with epsilon=49.33%...
# starting training on rollout information...
# iteration=76 Average Reward per episode: 558.87
# #################################
#  new best 558.8690165767699 saving Q...
# #################################
# loading best result
# rollout iteration 77 with epsilon=48.67%...
# starting training on rollout information...
# iteration=77 Average Reward per episode: 561.20
# #################################
#  new best 561.2037421040447 saving Q...
# #################################
# loading best result
# rollout iteration 78 with epsilon=48.00%...
# starting training on rollout information...
# iteration=78 Average Reward per episode: 559.96
# loading best result
# rollout iteration 79 with epsilon=47.33%...
# starting training on rollout information...
# iteration=79 Average Reward per episode: 552.25
# loading best result
# rollout iteration 80 with epsilon=46.67%...
# starting training on rollout information...
# iteration=80 Average Reward per episode: 553.60
# loading best result
# rollout iteration 81 with epsilon=46.00%...
# starting training on rollout information...
# iteration=81 Average Reward per episode: 555.07
# loading best result
# rollout iteration 82 with epsilon=45.33%...
# starting training on rollout information...
# iteration=82 Average Reward per episode: 555.77
# loading best result
# rollout iteration 83 with epsilon=44.67%...
# starting training on rollout information...
# iteration=83 Average Reward per episode: 560.03
# loading best result
# rollout iteration 84 with epsilon=44.00%...
# starting training on rollout information...
# iteration=84 Average Reward per episode: 554.89
# loading best result
# rollout iteration 85 with epsilon=43.33%...
# starting training on rollout information...
# iteration=85 Average Reward per episode: 555.44
# loading best result
# rollout iteration 86 with epsilon=42.67%...
# starting training on rollout information...
# iteration=86 Average Reward per episode: 558.52
# loading best result
# rollout iteration 87 with epsilon=42.00%...
# starting training on rollout information...
# iteration=87 Average Reward per episode: 534.17
# loading best result
# rollout iteration 88 with epsilon=41.33%...
# starting training on rollout information...
# iteration=88 Average Reward per episode: 556.63
# loading best result
# rollout iteration 89 with epsilon=40.67%...
# starting training on rollout information...
# iteration=89 Average Reward per episode: 559.12
# loading best result
# rollout iteration 90 with epsilon=40.00%...
# starting training on rollout information...
# iteration=90 Average Reward per episode: 557.11
# loading best result
# rollout iteration 91 with epsilon=39.33%...
# starting training on rollout information...
# iteration=91 Average Reward per episode: 0.00
# loading best result
# rollout iteration 92 with epsilon=38.67%...
# starting training on rollout information...
# iteration=92 Average Reward per episode: 548.63
# loading best result
# rollout iteration 93 with epsilon=38.00%...
# starting training on rollout information...
# iteration=93 Average Reward per episode: 558.94
# loading best result
# rollout iteration 94 with epsilon=37.33%...
# starting training on rollout information...
# iteration=94 Average Reward per episode: 560.77
# loading best result
# rollout iteration 95 with epsilon=36.67%...
# starting training on rollout information...
# iteration=95 Average Reward per episode: 557.17
# loading best result
# rollout iteration 96 with epsilon=36.00%...
# starting training on rollout information...
# iteration=96 Average Reward per episode: 554.90
# loading best result
# rollout iteration 97 with epsilon=35.33%...
# starting training on rollout information...
# iteration=97 Average Reward per episode: 538.98
# loading best result
# rollout iteration 98 with epsilon=34.67%...
# starting training on rollout information...
# iteration=98 Average Reward per episode: 553.58
# loading best result
# rollout iteration 99 with epsilon=34.00%...
# starting training on rollout information...
# iteration=99 Average Reward per episode: 551.68
# loading best result
# loading best result

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.show()

# %%
# 1. Load the optimal weights from your best training checkpoint
Q.load_state_dict(torch.load('Q-checkpoint'))

# ==========================================================
# FIX: Explicitly inject the missing render metadata attribute for Gymnasium
# ==========================================================
env.metadata = {"render_modes": ["human"]}
# ==========================================================

# 2. Re-verify the visualization routine with scalar stepping
def watch_final_policy(Q, env):
    with torch.no_grad():
        # Setup the Q-value inference lambda function
        Qfun = lambda x: Q(torch.tensor(x[None, :], dtype=torch.float32))[0].numpy() 
        
        try:
            obs, info = env.reset() 
            env.render() # Opens the simulator visual display window
            time.sleep(1) # Brief pause so you can get ready to watch
            
            rewards_accumulator = 0
            while True: 
                # Network predicts the discrete action choice index (0 to 6)
                action_idx = np.argmax(Qfun(obs)) 
                
                # Extract the pure scalar voltage matching your disk environment requirements
                voltage_action = float(discrete_actions[action_idx])
                
                # Step the environment forward using the pure scalar value
                obs_next, reward, terminated, truncated, info = env.step(voltage_action) 
                obs = np.array(obs_next, dtype=np.float32) 
                
                rewards_accumulator += reward
                
                # Match your step time delta (dt=0.025) for a smooth, true-to-life animation speed
                time.sleep(0.025) 
                env.render() 
                
                if terminated or truncated: 
                    print(f"Episode finished! Total accumulated reward: {rewards_accumulator:.2f}")
                    time.sleep(1.0) # Hold the final frame for a second
                    break  
        finally: 
            env.close() # Clean up and close the visualization window safely

# 3. Trigger the animation!
watch_final_policy(Q, env)
# Out:
# Episode finished! Total accumulated reward: 561.04

# %%
Q.load_state_dict(torch.load('Q-checkpoint'))
show(Q, env)

# %%
import gym_unbalanced_disk
import gymnasium
import numpy as np
import torch
from matplotlib import pyplot as plt

umax = 3.0

Q.load_state_dict(torch.load('Q-checkpoint'))
Q.eval()

env = gym_unbalanced_disk.UnbalancedDisk_exp(
    umax=umax,
    dt=0.025
)

# logs
theta_list = []
theta_deg_list = []
omega_list = []
action_list = []
reward_list = []
qvalue_list = []

obs, info = env.reset()

print("=== REAL HARDWARE DEBUG ===")

try:

    with torch.no_grad():

        Qfun = lambda x: Q(
            torch.tensor(x[None,:], dtype=torch.float32)
        )[0].numpy()

        for step in range(600):

            # --------------------------------------------------
            # Estado recibido del hardware
            # --------------------------------------------------

            th = float(obs[0])
            omega = float(obs[1])

            obs_sincos = np.array([
                np.sin(th),
                np.cos(th),
                0.2*omega
            ], dtype=np.float32)

            # --------------------------------------------------
            # Evaluar red
            # --------------------------------------------------

            qvals = Qfun(obs_sincos)

            action_idx = np.argmax(qvals)

            voltage = float(
                discrete_actions[action_idx]
            )

            # --------------------------------------------------
            # Logs
            # --------------------------------------------------

            theta_deg = np.degrees(
                np.arctan2(
                    obs_sincos[0],
                    obs_sincos[1]
                )
            )

            theta_list.append(th)
            theta_deg_list.append(theta_deg)
            omega_list.append(omega)
            action_list.append(voltage)
            qvalue_list.append(qvals.copy())

            # --------------------------------------------------
            # Debug cada 20 pasos
            # --------------------------------------------------

            if step % 20 == 0:

                print(
                    f"step={step:4d}"
                    f" | theta={theta_deg:7.1f}°"
                    f" | omega={omega:8.3f}"
                    f" | u={voltage:5.2f}V"
                )

                print(
                    f"    sin={obs_sincos[0]: .3f}"
                    f" cos={obs_sincos[1]: .3f}"
                )

                print(
                    f"    Qmax={np.max(qvals): .3f}"
                    f"  Qmin={np.min(qvals): .3f}"
                )

            # --------------------------------------------------
            # Aplicar acción
            # --------------------------------------------------

            obs, reward, terminated, truncated, info = env.step(
                voltage
            )

            reward_list.append(reward)

            if terminated or truncated:

                print(
                    f"\nEpisode ended at step {step}"
                )

                break

finally:

    print("\nStopping hardware safely...")

    env.reset()
    env.close()
# Out:
# === REAL HARDWARE DEBUG ===
# step=   0 | theta=    0.0° | omega=  -2.351 | u=-3.00V
#     sin= 0.000 cos= 1.000
#     Qmax= 95.602  Qmin= 90.120
# step=  20 | theta=   12.4° | omega= -14.514 | u=-2.00V
#     sin= 0.215 cos= 0.977
#     Qmax= 102.085  Qmin= 97.644
# step=  40 | theta= -149.4° | omega=   7.189 | u=-3.00V
#     sin=-0.509 cos=-0.861
#     Qmax= 134.721  Qmin= 126.765
# step=  60 | theta=   76.5° | omega=  14.419 | u=-1.00V
#     sin= 0.972 cos= 0.233
#     Qmax= 128.688  Qmin= 124.544
# step=  80 | theta=  -16.0° | omega=  18.964 | u= 3.00V
#     sin=-0.276 cos= 0.961
#     Qmax= 98.426  Qmin= 93.755
# step= 100 | theta= -155.5° | omega=  13.216 | u=-3.00V
#     sin=-0.414 cos=-0.910
#     Qmax= 135.177  Qmin= 127.208
# step= 120 | theta=  147.8° | omega=  10.512 | u= 3.00V
#     sin= 0.533 cos=-0.846
#     Qmax= 142.683  Qmin= 130.386
# step= 140 | theta=    7.4° | omega=  19.184 | u=-3.00V
#     sin= 0.128 cos= 0.992
#     Qmax= 95.172  Qmin= 91.929
# step= 160 | theta= -104.4° | omega=   3.706 | u= 3.00V
#     sin=-0.969 cos=-0.249
#     Qmax= 122.760  Qmin= 118.945
# step= 180 | theta= -157.5° | omega= -10.870 | u=-3.00V
#     sin=-0.383 cos=-0.924
#     Qmax= 149.083  Qmin= 142.697
# step= 200 | theta= -121.9° | omega= -17.985 | u=-3.00V
#     sin=-0.849 cos=-0.528
#     Qmax= 130.627  Qmin= 122.151
# step= 220 | theta= -131.8° | omega= -12.911 | u=-3.00V
#     sin=-0.746 cos=-0.666
#     Qmax= 135.247  Qmin= 124.640
# step= 240 | theta= -112.7° | omega= -20.923 | u=-3.00V
#     sin=-0.923 cos=-0.386
#     Qmax= 125.922  Qmin= 120.213
# step= 260 | theta=  168.3° | omega= -19.039 | u= 3.00V
#     sin= 0.203 cos=-0.979
#     Qmax= 139.204  Qmin= 126.493
# step= 280 | theta=   88.6° | omega= -21.341 | u=-2.00V
#     sin= 1.000 cos= 0.025
#     Qmax= 129.210  Qmin= 123.253
# step= 300 | theta=  -92.9° | omega= -22.730 | u=-2.00V
#     sin=-0.999 cos=-0.050
#     Qmax= 121.476  Qmin= 116.661
# step= 320 | theta=  146.9° | omega= -22.243 | u= 2.00V
#     sin= 0.546 cos=-0.838
#     Qmax= 122.671  Qmin= 119.215
# step= 340 | theta=   93.1° | omega= -20.681 | u=-2.00V
#     sin= 0.999 cos=-0.053
#     Qmax= 129.590  Qmin= 123.910
# step= 360 | theta=  -30.6° | omega= -27.694 | u=-2.00V
#     sin=-0.509 cos= 0.861
#     Qmax= 104.233  Qmin= 97.953
# step= 380 | theta=  -66.2° | omega= -25.227 | u= 1.00V
#     sin=-0.915 cos= 0.403
#     Qmax= 113.605  Qmin= 111.076
# step= 400 | theta= -106.2° | omega= -20.626 | u=-3.00V
#     sin=-0.960 cos=-0.279
#     Qmax= 123.208  Qmin= 119.434
# step= 420 | theta= -153.5° | omega= -16.762 | u=-3.00V
#     sin=-0.446 cos=-0.895
#     Qmax= 150.440  Qmin= 143.601
# step= 440 | theta=  117.0° | omega= -21.519 | u=-1.00V
#     sin= 0.891 cos=-0.454
#     Qmax= 127.557  Qmin= 124.164
# step= 460 | theta=  -29.5° | omega= -25.274 | u=-2.00V
#     sin=-0.493 cos= 0.870
#     Qmax= 103.618  Qmin= 97.558
# step= 480 | theta=  -54.2° | omega= -23.830 | u=-2.00V
#     sin=-0.811 cos= 0.585
#     Qmax= 109.347  Qmin= 106.709
# step= 500 | theta= -111.6° | omega= -20.970 | u=-3.00V
#     sin=-0.930 cos=-0.368
#     Qmax= 125.371  Qmin= 120.029
# step= 520 | theta= -111.8° | omega= -19.746 | u=-3.00V
#     sin=-0.929 cos=-0.371
#     Qmax= 124.703  Qmin= 119.745
# step= 540 | theta= -101.2° | omega= -22.683 | u=-3.00V
#     sin=-0.981 cos=-0.194
#     Qmax= 122.908  Qmin= 119.211
# step= 560 | theta= -161.6° | omega= -19.306 | u=-2.00V
#     sin=-0.315 cos=-0.949
#     Qmax= 148.620  Qmin= 145.857
# step= 580 | theta=   83.5° | omega= -23.885 | u=-2.00V
#     sin= 0.994 cos= 0.113
#     Qmax= 128.347  Qmin= 122.295
#
# Stopping hardware safely...

# %%
env.close()

# %%
for i in range(200):
    action = np.random.randint(num_actions)
    voltage = float(discrete_actions[action])

    obs, reward, term, trunc, info = env.step(voltage)

    if i % 20 == 0:
        print(
            f"sin={obs[0]:+.3f} "
            f"cos={obs[1]:+.3f} "
            f"omega={obs[2]:+.3f}"
        )
# Out:
# sin=+0.038 cos=+0.999 omega=+0.590
# sin=+0.302 cos=+0.953 omega=+0.161
# sin=+0.094 cos=+0.996 omega=+2.230
# sin=+0.082 cos=+0.997 omega=-0.858
# sin=-0.262 cos=+0.965 omega=+0.784
# sin=-0.001 cos=+1.000 omega=-0.469
# sin=-0.086 cos=+0.996 omega=-2.025
# sin=-0.045 cos=+0.999 omega=-0.608
# sin=-0.017 cos=+1.000 omega=+0.822
# sin=-0.090 cos=+0.996 omega=-1.455

# %%
torch.onnx.export(Q, dummy_input, "model.onnx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 torch.onnx.export(Q, dummy_input, "model.onnx")
#
# NameError: name 'dummy_input' is not defined

# %%
import gym_unbalanced_disk
import numpy as np
import time

env = gym_unbalanced_disk.UnbalancedDisk_exp(
    umax=3.0,
    dt=0.025
)

obs, info = env.reset()

print("\n=== SENSOR TEST ===")
print("Mueve el péndulo a mano")
print("Abajo -> anota theta")
print("Arriba -> anota theta")
print("Muévelo lento -> observa omega")
print()

try:

    for k in range(400):

        theta = float(obs[0])
        omega = float(obs[1])

        theta_deg = np.degrees(theta)

        print(
            f"theta = {theta:8.4f} rad"
            f" | theta_deg = {theta_deg:8.2f}°"
            f" | omega = {omega:8.4f} rad/s"
        )

        # NO CONTROL
        obs, reward, terminated, truncated, info = env.step(0.0)

        time.sleep(0.05)

except KeyboardInterrupt:
    pass

finally:

    print("\nStopping hardware safely...")

    env.reset()
    env.close()
# Out:
# === SENSOR TEST ===
# Mueve el péndulo a mano
# Abajo -> anota theta
# Arriba -> anota theta
# Muévelo lento -> observa omega
#
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.1271 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.3472 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.3472 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.3472 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.3472 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.9071 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.9110 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.2992 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.7393 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.7393 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.8592 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.9071 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.7393 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.4192 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.8592 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.6910 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.4671 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.0792 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.3472 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.1992 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -3.7432 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.0270 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.3511 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.4192 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.9110 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.1310 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.3472 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.7393 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.5193 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.6871 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.1271 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.8592 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.0270 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -0.6871 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -1.9110 rad/s
# theta =   0.0000 rad | theta_deg =     0.00° | omega =  -2.2992 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -2.9593 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -3.7432 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -2.9593 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -1.6910 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -3.5232 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -0.9071 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -2.5193 rad/s
# theta =  -0.0031 rad | theta_deg =    -0.18° | omega =  -3.3032 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.9632 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.2471 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.0270 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.3511 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.0270 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.6871 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =   0.1930 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.8592 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6392 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -4.6233 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.0792 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.2471 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6392 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.3511 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.6871 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6910 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.3032 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.6871 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.8592 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6392 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.8592 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.8592 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.0270 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.3511 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.7591 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.7432 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.0270 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6392 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.0792 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.6871 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =   0.1930 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.5232 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.2471 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.9110 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6910 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.4192 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.9110 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.5232 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.4192 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.5232 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.3511 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.8592 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.2471 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.4192 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.7432 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.1310 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =   0.4130 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6910 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.0792 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6392 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.3032 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.2992 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6910 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.4192 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.9071 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.1271 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.6871 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.9593 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.0792 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.3032 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.4671 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -2.5193 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.3472 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -1.6910 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -3.3032 rad/s
# theta =   0.0628 rad | theta_deg =     3.60° | omega =   0.6330 rad/s
# theta =   0.3864 rad | theta_deg =    22.14° | omega =   4.7172 rad/s
# theta =   0.7791 rad | theta_deg =    44.64° | omega =   1.1249 rad/s
# theta =   1.0901 rad | theta_deg =    62.46° | omega =   2.9570 rad/s
# theta =   1.4546 rad | theta_deg =    83.34° | omega =   2.2970 rad/s
# theta =   1.7373 rad | theta_deg =    99.54° | omega =   3.3971 rad/s
# theta =   2.0923 rad | theta_deg =   119.88° | omega =   0.1210 rad/s
# theta =   2.4724 rad | theta_deg =   141.66° | omega =   3.1770 rad/s
# theta =   2.8306 rad | theta_deg =   162.18° | omega =   1.5649 rad/s
# theta =   3.2170 rad | theta_deg =   184.32° | omega =  -0.3191 rad/s
# theta =   3.2421 rad | theta_deg =   185.76° | omega =  -4.6233 rad/s
# theta =   3.1981 rad | theta_deg =   183.24° | omega =  -0.6871 rad/s
# theta =   3.2296 rad | theta_deg =   185.04° | omega =  -2.9593 rad/s
# theta =   3.2201 rad | theta_deg =   184.50° | omega =  -3.3032 rad/s
# theta =   3.2170 rad | theta_deg =   184.32° | omega =  -1.1271 rad/s
# theta =   3.2138 rad | theta_deg =   184.14° | omega =   0.4130 rad/s
# theta =   3.1510 rad | theta_deg =   180.54° | omega =  -1.9110 rad/s
# theta =   3.1039 rad | theta_deg =   177.84° | omega =  -1.6392 rad/s
# theta =   3.1008 rad | theta_deg =   177.66° | omega =  -2.0792 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -1.1992 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -3.5232 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -3.5232 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -1.9110 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -2.2992 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -1.6910 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -0.4671 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -2.7393 rad/s
# theta =   3.0788 rad | theta_deg =   176.40° | omega =  -2.0792 rad/s
# theta =   3.0788 rad | theta_deg =   176.40° | omega =  -2.2992 rad/s
# theta =   3.0819 rad | theta_deg =   176.58° | omega =  -2.5193 rad/s
# theta =   3.0819 rad | theta_deg =   176.58° | omega =  -1.3472 rad/s
# theta =   3.0756 rad | theta_deg =   176.22° | omega =  -2.5193 rad/s
# theta =   3.0379 rad | theta_deg =   174.06° | omega =  -2.3511 rad/s
# theta =   2.9405 rad | theta_deg =   168.48° | omega =  -1.1271 rad/s
# theta =   2.6641 rad | theta_deg =   152.64° | omega =  -5.2833 rad/s
# theta =   2.3750 rad | theta_deg =   136.08° | omega =  -4.8433 rad/s
# theta =   2.0546 rad | theta_deg =   117.72° | omega =  -5.7234 rad/s
# theta =   1.7530 rad | theta_deg =   100.44° | omega =  -5.0633 rad/s
# theta =   1.4985 rad | theta_deg =    85.86° | omega =  -3.6712 rad/s
# theta =   1.2158 rad | theta_deg =    69.66° | omega =  -4.3312 rad/s
# theta =   0.9927 rad | theta_deg =    56.88° | omega =  -4.1112 rad/s
# theta =   0.7351 rad | theta_deg =    42.12° | omega =  -6.1634 rad/s
# theta =   0.4461 rad | theta_deg =    25.56° | omega =  -5.9434 rad/s
# theta =   0.1822 rad | theta_deg =    10.44° | omega =  -3.0111 rad/s
# theta =  -0.0094 rad | theta_deg =    -0.54° | omega =  -5.5033 rad/s
# theta =  -0.1477 rad | theta_deg =    -8.46° | omega =  -2.5193 rad/s
# theta =  -0.1477 rad | theta_deg =    -8.46° | omega =  -0.2471 rad/s
# theta =  -0.1477 rad | theta_deg =    -8.46° | omega =  -0.2471 rad/s
# theta =  -0.1477 rad | theta_deg =    -8.46° | omega =  -1.8592 rad/s
# theta =  -0.1477 rad | theta_deg =    -8.46° | omega =  -2.5193 rad/s
# theta =  -0.1445 rad | theta_deg =    -8.28° | omega =   0.4130 rad/s
# theta =  -0.1257 rad | theta_deg =    -7.20° | omega =  -0.6871 rad/s
# theta =  -0.1665 rad | theta_deg =    -9.54° | omega =  -2.7911 rad/s
# theta =  -0.4021 rad | theta_deg =   -23.04° | omega =  -5.5552 rad/s
# theta =  -0.7383 rad | theta_deg =   -42.30° | omega =  -7.1673 rad/s
# theta =  -1.2032 rad | theta_deg =   -68.94° | omega =  -6.9473 rad/s
# theta =  -1.6116 rad | theta_deg =   -92.34° | omega =  -4.1112 rad/s
# theta =  -2.0452 rad | theta_deg =  -117.18° | omega =  -7.3873 rad/s
# theta =  -2.5070 rad | theta_deg =  -143.64° | omega =  -5.9952 rad/s
# theta =  -2.9091 rad | theta_deg =  -166.68° | omega =  -6.6034 rad/s
# theta =  -3.2515 rad | theta_deg =  -186.30° | omega =  -3.8912 rad/s
# theta =  -3.3489 rad | theta_deg =  -191.88° | omega =  -0.9791 rad/s
# theta =  -3.1950 rad | theta_deg =  -183.06° | omega =   0.8530 rad/s
# theta =  -3.1636 rad | theta_deg =  -181.26° | omega =  -1.8592 rad/s
# theta =  -3.1730 rad | theta_deg =  -181.80° | omega =  -1.6910 rad/s
# theta =  -3.1699 rad | theta_deg =  -181.62° | omega =  -3.3032 rad/s
# theta =  -3.1699 rad | theta_deg =  -181.62° | omega =  -2.7393 rad/s
# theta =  -3.1542 rad | theta_deg =  -180.72° | omega =  -1.8592 rad/s
# theta =  -3.0788 rad | theta_deg =  -176.40° | omega =  -0.7591 rad/s
# theta =  -2.8903 rad | theta_deg =  -165.60° | omega =   0.3410 rad/s
# theta =  -2.5792 rad | theta_deg =  -147.78° | omega =   0.9048 rad/s
# theta =  -2.2682 rad | theta_deg =  -129.96° | omega =   3.1770 rad/s
# theta =  -1.9572 rad | theta_deg =  -112.14° | omega =   2.9570 rad/s
# theta =  -1.6713 rad | theta_deg =   -95.76° | omega =   1.2931 rad/s
# theta =  -1.3635 rad | theta_deg =   -78.12° | omega =   3.8371 rad/s
# theta =  -1.0116 rad | theta_deg =   -57.96° | omega =   0.9048 rad/s
# theta =  -0.6754 rad | theta_deg =   -38.70° | omega =   2.5170 rad/s
# theta =  -0.3456 rad | theta_deg =   -19.80° | omega =   0.6330 rad/s
# theta =  -0.0785 rad | theta_deg =    -4.50° | omega =   1.9531 rad/s
# theta =  -0.0157 rad | theta_deg =    -0.90° | omega =  -1.1271 rad/s
# theta =  -0.0346 rad | theta_deg =    -1.98° | omega =  -1.9110 rad/s
# theta =  -0.0346 rad | theta_deg =    -1.98° | omega =  -3.3032 rad/s
# theta =  -0.0377 rad | theta_deg =    -2.16° | omega =  -0.9071 rad/s
# theta =  -0.0471 rad | theta_deg =    -2.70° | omega =  -1.6910 rad/s
# theta =  -0.0471 rad | theta_deg =    -2.70° | omega =  -0.4671 rad/s
# theta =  -0.0408 rad | theta_deg =    -2.34° | omega =  -1.6910 rad/s
# theta =   0.0346 rad | theta_deg =     1.98° | omega =  -0.9791 rad/s
# theta =   0.3299 rad | theta_deg =    18.90° | omega =   3.6171 rad/s
# theta =   1.0022 rad | theta_deg =    57.42° | omega =   6.6012 rad/s
# theta =   1.5582 rad | theta_deg =    89.28° | omega =   5.5972 rad/s
# theta =   2.4222 rad | theta_deg =   138.78° | omega =   9.2414 rad/s
# theta =   3.3050 rad | theta_deg =   189.36° | omega =   5.5972 rad/s
# theta =   3.5594 rad | theta_deg =   203.94° | omega =  -3.7432 rad/s
# theta =   3.3709 rad | theta_deg =   193.14° | omega =  -4.3312 rad/s
# theta =   3.2673 rad | theta_deg =   187.20° | omega =  -2.9593 rad/s
# theta =   3.2735 rad | theta_deg =   187.56° | omega =  -0.2471 rad/s
# theta =   3.2767 rad | theta_deg =   187.74° | omega =  -2.2992 rad/s
# theta =   3.2704 rad | theta_deg =   187.38° | omega =  -3.7432 rad/s
# theta =   3.0850 rad | theta_deg =   176.76° | omega =  -4.3312 rad/s
# theta =   2.5855 rad | theta_deg =   148.14° | omega =  -6.6552 rad/s
# theta =   2.0326 rad | theta_deg =   116.46° | omega =  -7.3873 rad/s
# theta =   1.5896 rad | theta_deg =    91.08° | omega =  -5.5033 rad/s
# theta =   1.2409 rad | theta_deg =    71.10° | omega =  -5.7234 rad/s
# theta =   0.9519 rad | theta_deg =    54.54° | omega =  -5.9434 rad/s
# theta =   0.5372 rad | theta_deg =    30.78° | omega =  -4.9913 rad/s
# theta =   0.2293 rad | theta_deg =    13.14° | omega =  -3.8912 rad/s
# theta =   0.0440 rad | theta_deg =     2.52° | omega =  -2.9593 rad/s
# theta =   0.0346 rad | theta_deg =     1.98° | omega =  -0.4671 rad/s
# theta =   0.0440 rad | theta_deg =     2.52° | omega =  -2.9593 rad/s
# theta =   0.0408 rad | theta_deg =     2.34° | omega =  -1.1271 rad/s
# theta =  -0.1351 rad | theta_deg =    -7.74° | omega =  -6.6552 rad/s
# theta =  -0.7037 rad | theta_deg =   -40.32° | omega =  -9.5875 rad/s
# theta =  -1.4577 rad | theta_deg =   -83.52° | omega = -11.9115 rad/s
# theta =  -2.4724 rad | theta_deg =  -141.66° | omega = -14.8956 rad/s
# theta =  -3.4715 rad | theta_deg =  -198.90° | omega =  -8.9274 rad/s
# theta =  -3.5312 rad | theta_deg =  -202.32° | omega =   1.9531 rad/s
# theta =  -3.3929 rad | theta_deg =  -194.40° | omega =  -2.7393 rad/s
# theta =  -3.4777 rad | theta_deg =  -199.26° | omega =  -2.9593 rad/s
# theta =  -3.4275 rad | theta_deg =  -196.38° | omega =  -0.0270 rad/s
# theta =  -3.3395 rad | theta_deg =  -191.34° | omega =  -0.4671 rad/s
# theta =  -3.0316 rad | theta_deg =  -173.70° | omega =   3.5451 rad/s
# theta =  -2.4536 rad | theta_deg =  -140.58° | omega =   3.9851 rad/s
# theta =  -1.9541 rad | theta_deg =  -111.96° | omega =   1.5649 rad/s
# theta =  -1.5959 rad | theta_deg =   -91.44° | omega =   3.1770 rad/s
# theta =  -1.1247 rad | theta_deg =   -64.44° | omega =   2.5170 rad/s
# theta =  -0.6283 rad | theta_deg =   -36.00° | omega =   3.5451 rad/s
# theta =  -0.1916 rad | theta_deg =   -10.98° | omega =   3.3971 rad/s
# theta =   0.0126 rad | theta_deg =     0.72° | omega =  -2.7393 rad/s
# theta =  -0.0063 rad | theta_deg =    -0.36° | omega =  -0.2471 rad/s
# theta =  -0.0440 rad | theta_deg =    -2.52° | omega =  -1.6910 rad/s
# theta =  -0.0440 rad | theta_deg =    -2.52° | omega =  -0.4671 rad/s
# theta =  -0.0440 rad | theta_deg =    -2.52° | omega =  -0.0270 rad/s
# theta =  -0.0440 rad | theta_deg =    -2.52° | omega =  -1.8592 rad/s
# theta =  -0.0503 rad | theta_deg =    -2.88° | omega =  -3.3032 rad/s
# theta =  -0.0503 rad | theta_deg =    -2.88° | omega =  -1.6910 rad/s
# theta =  -0.0503 rad | theta_deg =    -2.88° | omega =  -3.7432 rad/s
# theta =  -0.0314 rad | theta_deg =    -1.80° | omega =   0.4130 rad/s
# theta =   0.0754 rad | theta_deg =     4.32° | omega =  -0.3191 rad/s
# theta =   0.2293 rad | theta_deg =    13.14° | omega =  -0.5391 rad/s
# theta =   0.4021 rad | theta_deg =    23.04° | omega =  -0.6871 rad/s
# theta =   0.5781 rad | theta_deg =    33.12° | omega =   1.7331 rad/s
# theta =   0.7948 rad | theta_deg =    45.54° | omega =   1.5131 rad/s
# theta =   1.0147 rad | theta_deg =    58.14° | omega =   1.2931 rad/s
# theta =   1.2472 rad | theta_deg =    71.46° | omega =   2.2970 rad/s
# theta =   1.4420 rad | theta_deg =    82.62° | omega =  -0.9791 rad/s
# theta =   1.5331 rad | theta_deg =    87.84° | omega =   1.0730 rad/s
# theta =   1.6933 rad | theta_deg =    97.02° | omega =   0.4130 rad/s
# theta =   1.7373 rad | theta_deg =    99.54° | omega =  -3.3032 rad/s
# theta =   1.6431 rad | theta_deg =    94.14° | omega =  -3.5232 rad/s
# theta =   1.6085 rad | theta_deg =    92.16° | omega =  -1.6392 rad/s
# theta =   1.6085 rad | theta_deg =    92.16° | omega =  -2.7393 rad/s
# theta =   1.6085 rad | theta_deg =    92.16° | omega =  -0.6871 rad/s
# theta =   1.6085 rad | theta_deg =    92.16° | omega =  -1.6910 rad/s
# theta =   1.5300 rad | theta_deg =    87.66° | omega =  -5.7234 rad/s
# theta =   1.2723 rad | theta_deg =    72.90° | omega =  -5.9434 rad/s
# theta =   1.0399 rad | theta_deg =    59.58° | omega =  -5.5033 rad/s
# theta =   0.7383 rad | theta_deg =    42.30° | omega =  -4.9913 rad/s
# theta =   0.3927 rad | theta_deg =    22.50° | omega =  -5.0633 rad/s
# theta =   0.1916 rad | theta_deg =    10.98° | omega =  -2.7911 rad/s
# theta =   0.0848 rad | theta_deg =     4.86° | omega =  -3.3032 rad/s
# theta =   0.0848 rad | theta_deg =     4.86° | omega =  -0.2471 rad/s
# theta =   0.0848 rad | theta_deg =     4.86° | omega =  -2.9593 rad/s
# theta =   0.0817 rad | theta_deg =     4.68° | omega =  -1.6910 rad/s
# theta =   0.0283 rad | theta_deg =     1.62° | omega =  -2.5193 rad/s
# theta =  -0.2325 rad | theta_deg =   -13.32° | omega =  -5.3351 rad/s
# theta =  -0.5812 rad | theta_deg =   -33.30° | omega =  -5.5033 rad/s
# theta =  -0.9456 rad | theta_deg =   -54.18° | omega =  -6.9473 rad/s
# theta =  -1.3006 rad | theta_deg =   -74.52° | omega =  -5.9434 rad/s
# theta =  -1.6148 rad | theta_deg =   -92.52° | omega =  -6.3834 rad/s
# theta =  -1.8315 rad | theta_deg =  -104.94° | omega =  -2.5193 rad/s
# theta =  -1.7938 rad | theta_deg =  -102.78° | omega =  -0.0270 rad/s
# theta =  -1.7781 rad | theta_deg =  -101.88° | omega =  -1.1271 rad/s
# theta =  -1.7781 rad | theta_deg =  -101.88° | omega =  -2.7393 rad/s
# theta =  -1.7781 rad | theta_deg =  -101.88° | omega =  -1.6392 rad/s
# theta =  -1.7781 rad | theta_deg =  -101.88° | omega =  -1.6392 rad/s
# theta =  -1.7090 rad | theta_deg =   -97.92° | omega =  -0.7591 rad/s
# theta =  -1.4985 rad | theta_deg =   -85.86° | omega =   0.6330 rad/s
# theta =  -1.1969 rad | theta_deg =   -68.58° | omega =   2.7370 rad/s
# theta =  -0.8011 rad | theta_deg =   -45.90° | omega =   2.6650 rad/s
# theta =  -0.4995 rad | theta_deg =   -28.62° | omega =   1.7849 rad/s
# theta =  -0.1696 rad | theta_deg =    -9.72° | omega =   3.3971 rad/s
# theta =   0.1508 rad | theta_deg =     8.64° | omega =   1.2931 rad/s
# theta =   0.0848 rad | theta_deg =     4.86° | omega =  -4.6233 rad/s
# theta =   0.0283 rad | theta_deg =     1.62° | omega =  -1.6392 rad/s
# theta =   0.0283 rad | theta_deg =     1.62° | omega =  -0.4671 rad/s
# theta =   0.0220 rad | theta_deg =     1.26° | omega =  -1.9110 rad/s
# theta =   0.0220 rad | theta_deg =     1.26° | omega =  -2.2992 rad/s
# theta =   0.0220 rad | theta_deg =     1.26° | omega =  -2.7393 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -3.7432 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -2.5193 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -3.3032 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -2.7393 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -1.3472 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -3.3032 rad/s
# theta =   0.0188 rad | theta_deg =     1.08° | omega =  -2.5193 rad/s
# theta =   0.0942 rad | theta_deg =     5.40° | omega =   0.4130 rad/s
# theta =   0.3801 rad | theta_deg =    21.78° | omega =   2.2250 rad/s
# theta =   0.8325 rad | theta_deg =    47.70° | omega =   4.4972 rad/s
# theta =   1.2975 rad | theta_deg =    74.34° | omega =   3.3971 rad/s
# theta =   1.6776 rad | theta_deg =    96.12° | omega =   2.2970 rad/s
# theta =   2.0200 rad | theta_deg =   115.74° | omega =   0.9048 rad/s
# theta =   2.3531 rad | theta_deg =   134.82° | omega =   1.3449 rad/s
# theta =   2.6358 rad | theta_deg =   151.02° | omega =   1.1249 rad/s
# theta =   2.8934 rad | theta_deg =   165.78° | omega =  -0.3191 rad/s
# theta =   3.1102 rad | theta_deg =   178.20° | omega =  -0.6871 rad/s
# theta =   3.1447 rad | theta_deg =   180.18° | omega =  -2.2992 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =  -1.1271 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =  -2.2992 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =  -2.5193 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =  -3.7432 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =  -3.0111 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =  -1.6392 rad/s
# theta =   3.1322 rad | theta_deg =   179.46° | omega =   0.1930 rad/s
# theta =   3.1290 rad | theta_deg =   179.28° | omega =  -1.9110 rad/s
#
# Stopping hardware safely...
