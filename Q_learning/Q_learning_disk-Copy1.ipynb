# %%
import gymnasium as gym
import gym_unbalanced_disk, time
import gymnasium.wrappers
import torch
import numpy as np

from torch import nn
from copy import deepcopy
from matplotlib import pyplot as plt

if not hasattr(gym_unbalanced_disk.UnbalancedDisk, '_old_reset'):
    gym_unbalanced_disk.UnbalancedDisk._old_reset = gym_unbalanced_disk.UnbalancedDisk.reset

def patched_reset(self, seed=None, options=None):
    # Call the original reset without the new keyword parameters
    return self._old_reset()

gym_unbalanced_disk.UnbalancedDisk.reset = patched_reset

raw_env = gym_unbalanced_disk.UnbalancedDisk(dt=0.025, umax=3.) 
env = gym.wrappers.TimeLimit(raw_env, max_episode_steps=200)


#env = gym_unbalanced_disk.UnbalancedDisk(dt=0.025, umax=3.) #alternative

obs, info = env.reset()
try:
    for i in range(200):
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample()) #random action
        print(obs, reward)
        env.render()
        time.sleep(1/24)
        if terminated or truncated:
            obs = env.reset()
finally: #this will always run
    env.close()
# Out:
# [-0.0204092  -1.73259756] 3.167688666569101e-11
# [-0.07279278 -2.32592936] 6.949710159692753e-11
# [-0.13890135 -2.930135  ] 1.8855832582555396e-10
# [-0.18301193 -0.84888842] 3.8024721425834025e-10
# [-0.19527261  0.04858401] 4.3685180927058784e-10
# [-0.17995841  1.11548602] 3.518839197064016e-10
# [-0.14814926  1.42878556] 2.1916739702042187e-10
# [-0.09862015  2.50461696] 1.0428400425359075e-10
# [-0.02338695  3.56314916] 3.239899604786597e-11
# [0.08466192 4.85452436] 8.30000982193832e-11
# [0.2069812  4.94063957] 5.194015313272049e-10
# [0.29929035 2.49343662] 1.9809165691368495e-09
# [0.34484585 1.07225487] 3.7046574999866732e-09
# [0.36676502 0.57837469] 4.934569273926553e-09
# [ 0.35966772 -1.0268996 ] 4.515310591158248e-09
# [ 0.30261733 -3.58706018] 2.003264164615113e-09
# [ 0.19167574 -5.06780284] 4.18126048156845e-10
# [ 0.06160579 -5.35219122] 5.870565328428882e-11
# [-0.08682351 -6.50462622] 8.906151401771584e-11
# [-0.21543666 -3.66206955] 5.926622109434652e-10
# [-0.31174941 -4.11025397] 2.3959247492955697e-09
# [-0.40921702 -3.57607123] 9.091518855948224e-09
# [-0.47451939 -1.60237423] 2.1714041286427233e-08
# [-0.48318358  0.94254597] 2.3856387646269664e-08
# [-0.46322296  0.52968779] 1.8676380027625596e-08
# [-0.45573738  0.07534884] 1.6886371905474044e-08
# [-0.43102745  2.05618416] 1.1770770876538911e-08
# [-0.33770192  5.11422566] 3.415260599061253e-09
# [-0.18920758  6.8254284 ] 3.986715846431315e-10
# [-0.03592078  5.34643431] 3.987398951828114e-11
# [0.08665255 4.3061841 ] 8.546721626209052e-11
# [0.18470913 3.52989435] 3.719609108336907e-10
# [0.2610824  2.63480683] 1.1435492771462585e-09
# [ 0.28923676 -0.32280507] 1.710686105968417e-09
# [ 0.26146274 -1.97502303] 1.1314335714808221e-09
# [ 0.1860316  -4.04850608] 3.764305654173948e-10
# [ 0.06461392 -5.43624469] 6.294186818683409e-11
# [-0.067983   -5.10611568] 6.449978107281705e-11
= gym.wrappers.TimeLimit(env,max_episode_steps=max_episode_steps) 

#def reward_fun(self):
#    cos_th = np.cos(self.th)
#    angle_reward = 0.5 * (1.0 - cos_th)
#    top_bonus = np.exp(-(1.0 + cos_th)**2 / 0.1)
#    return angle_reward + top_bonus

#env.unwrapped.reward_fun = reward_fun

def make_env():
    env = gym.make('unbalanced-disk-sincos-v0')
    env.unwrapped.reward_fun = lambda self: 0.5 * (1.0 - np.cos(self.th))**2
    return env

env = make_env()

# Definition of discrete actions
discrete_actions = np.array([
    -3.0, -2.0, -1.0, -0.5, -0.25,
    -0.1, -0.05, -0.02,
     0.0,
     0.02, 0.05, 0.1,
     0.25, 0.5, 1.0, 2.0, 3.0
])
num_actions = len(discrete_actions)

Q = Qfunction(env)
#test validity:
obs, info = env.reset()
obs_tensor = torch.tensor(obs,dtype=torch.float32)[None,:] #convert to an torch tensor with size (1, Nobs=6)
print('obs_tensor = ', obs_tensor)
print('Q(x) = ',Q(obs_tensor)) #output #(1,Naction=3)
# Out:
# obs_tensor =  tensor([[-2.8092e-03,  1.0000e+00,  1.0368e-04]])
# Q(x) =  tensor([[ 0.0850, -0.0517, -0.2641,  0.4198, -0.3391, -0.0048,  0.1985,  0.0867,
#          -0.1720,  0.0901, -0.0708, -0.4688,  0.1986,  0.1180,  0.0184, -0.0504,
#          -0.5934]], grad_fn=<AddmmBackward0>)
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %%
#visualize
def show(Q,env):
    with torch.no_grad():
        #you can use Qfun(obs) as a shorthand for the q function.
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy() #convert x to torch.tensor -> put in the Q function -> back to numpy
        try:
            obs, info = env.reset() #b)
            env.render() #b)
            time.sleep(1) #b)
            while True: #b)
                action = np.argmax(Qfun(obs)) #b)
                voltage_action = float(discrete_actions[action])
                obs, reward, terminated, truncated, info = env.step(voltage_action) #b)
                time.sleep(1/60) #b)
                env.render() #b)
                if terminated or truncated: #b)
                    time.sleep(0.5)  #b)
                    break  #b)
        finally: #this will always run even when an error occurs
            env.close()
 
Q = Qfunction(env)
#show(Q,env)

# %%
def rollout(Q, env, epsilon=0.1, N_rollout=10_000): 
    # Save the following arrays (using .append)
    Start_state = [] # hold an array of (x_t)
    Actions = []     # hold an array of (u_t)
    Rewards = []     # hold an array of (r_{t+1})
    End_state = []   # hold an array of (x_{t+1})
    Terminal = []    # hold an array of (terminal_{t+1})
    
    # Qfun(a numpy array of the obs) -> a numpy array of Q values
    Qfun = lambda x: Q(torch.tensor(x[None, :], dtype=torch.float32))[0].numpy() 
    
    with torch.no_grad():
        obs, info = env.reset()
        obs = np.array(obs, dtype=np.float32) 
        
        for i in range(N_rollout): 
            if np.random.uniform() > epsilon: 
                Qnow = Qfun(obs) 
                action = np.argmax(Qnow) 
            else: 
                action = np.random.randint(0, num_actions) 
                
            Start_state.append(obs) 
            Actions.append(action) 

            # FIX: Get the raw scalar float number out of the array mapping
            voltage_action = float(discrete_actions[action])
            
            # Pass the raw scalar value directly to the step function
            obs_next, reward, terminated, truncated, info = env.step(voltage_action) 
            obs_next = np.array(obs_next, dtype=np.float32) 

            Terminal.append(terminated) 
            Rewards.append(reward) 
            End_state.append(obs_next) 

            if terminated or truncated: 
                obs, info = env.reset() 
                obs = np.array(obs, dtype=np.float32) 
            else: 
                obs = obs_next 
                
    assert len(Start_state) == len(Actions) == len(Rewards) == len(End_state) == len(Terminal), \
        f'error in lengths: {len(Start_state)}=={len(Actions)}=={len(Rewards)}=={len(End_state)}=={len(Terminal)}'
        
    return np.array(Start_state), np.array(Actions), np.array(Rewards), np.array(End_state), np.array(Terminal).astype(int)

# Trigger and test
Q = Qfunction(env) 
Start_state, Actions, Rewards, End_state, Terminal = rollout(Q, env, N_rollout=300)
print("Data collected successfully! Shapes:")
print(f"States: {Start_state.shape}, Actions: {Actions.shape}, Rewards: {Rewards.shape}")
# Out:
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# C:\Users\timme\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\utils\passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# Data collected successfully! Shapes:
# States: (300, 3), Actions: (300,), Rewards: (300,)

# %%
def eval_Q(Q,env):
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:],dtype=torch.float32))[0].numpy()
        rewards_acc = 0 #d)
        obs, info = env.reset() #d)
        while True: #d)
            action = np.argmax(Qfun(obs)) #d)
            voltage_action = float(discrete_actions[action])
            obs, reward, terminated, truncated, info = env.step(voltage_action) #d)
            rewards_acc += reward #d)
            if terminated or truncated: #d)
                return rewards_acc #d)

Q = Qfunction(env) 
plt.plot([eval_Q(Q,env) for i in range(100)],'.') #d)
plt.show() #d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#      12                 return rewards_acc #d)
#      14 Q = Qfunction(env)
# ---> 15 plt.plot([eval_Q(Q,env) for i in range(100)],'.') #d)
#      16 plt.show() #d)
#
# Cell In[5], line 15, in <listcomp>(.0)
#      12                 return rewards_acc #d)
#      14 Q = Qfunction(env)
# ---> 15 plt.plot([eval_Q(Q,env) for i in range(100)],'.') #d)
#      16 plt.show() #d)
#
# Cell In[5], line 9, in eval_Q(Q, env)
#       7 action = np.argmax(Qfun(obs)) #d)
#       8 voltage_action = float(discrete_actions[action])
# ----> 9 obs, reward, terminated, truncated, info = env.step(voltage_action) #d)
#      10 rewards_acc += reward #d)
#      11 if terminated or truncated: #d)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)    123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gym_unbalanced_disk\envs\UnbalancedDisk.py:67, in UnbalancedDisk.step(self, action)
#      65     domegadt = -self.omega0**2*np.sin(th+self.delta_th) - friction + self.Ku*self.u
#      66     return np.array([dthdt, domegadt])
# ---> 67 sol = solve_ivp(f,[0,self.dt],[self.th,self.omega]) #integration
#      68 self.th, self.omega = sol.y[:,-1]
#      69 ##### End do not edit   #####
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\scipy\integrate\_ivp\ivp.py:650, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     648 status = None
#     649 while status is None:
# --> 650     message = solver.step()
#     652     if solver.status == 'finished':
#     653         status = 0
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\scipy\integrate\_ivp\base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\scipy\integrate\_ivp\rk.py:147, in RungeKutta._step_impl(self)
#     144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
# --> 147 error_norm = self._estimate_error_norm(self.K, h, scale)
#     149 if error_norm < 1:
#     150     if error_norm == 0:
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\scipy\integrate\_ivp\rk.py:109, in RungeKutta._estimate_error_norm(self, K, h, scale)
#     108 def _estimate_error_norm(self, K, h, scale):
# --> 109     return norm(self._estimate_error(K, h) / scale)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\scipy\integrate\_ivp\common.py:65, in norm(x)
#      63 def norm(x):
#      64     """Compute RMS norm."""
# ---> 65     return np.linalg.norm(x) / x.size ** 0.5
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\numpy\linalg\linalg.py:2552, in norm(x, ord, axis, keepdims)
#    2550     sqnorm = x_real.dot(x_real) + x_imag.dot(x_imag)
#    2551 else:
# -> 2552     sqnorm = x.dot(x)
#    2553 ret = sqrt(sqnorm)
#    2554 if keepdims:
#
# KeyboardInterrupt:

# %%
def DQN_rollout(Q, optimizer, env, gamma=0.98, use_target_net=False, N_iterations=21, N_rollout=20000, \
                N_epochs=10, batch_size=32, N_evals=10, target_net_update_feq=100):
    best = -float('inf')
    torch.save(Q.state_dict(),'Q-checkpoint')
    try:
        for iteration in range(N_iterations):
            epsilon = max(0.05, 1.0 - iteration/(N_iterations*1.5))
            print(f'rollout iteration {iteration} with epsilon={epsilon:.2%}...')
            
            #2. rollout
            Start_state, Actions, Rewards, End_state, Terminal = rollout(Q, env, epsilon=epsilon, N_rollout=N_rollout) #e) 2.
            
            #Data conversion, no changes required
            convert = lambda x: [torch.tensor(xi,dtype=torch.float32) for xi in x]
            Start_state, Rewards, End_state, Terminal = convert([Start_state, Rewards, End_state, Terminal])
            Actions = Actions.astype(int)

            # Shuffle rollout data before batching
            perm = torch.randperm(len(Start_state))
            Start_state = Start_state[perm]
            Actions      = Actions[perm]
            Rewards      = Rewards[perm]
            End_state    = End_state[perm]
            Terminal     = Terminal[perm]

            print('starting training on rollout information...')
            t = 0
            for epoch in range(N_epochs): 
                for i in range(batch_size,len(Start_state)+1,batch_size): 
                    if t%target_net_update_feq==0:
                        Qtarget = deepcopy(Q) #g)
                        pass
                    t += 1
                    
                    Start_state_batch, Actions_batch, Rewards_batch, End_state_batch, Terminal_batch = [d[i-batch_size:i] for d in \
                                                                                                        [Start_state, Actions, Rewards, End_state, Terminal]] #e=) 3.
                    
                    with torch.no_grad(): #3.
                        if use_target_net:
                            pass
                            maxQ = torch.max(Qtarget(End_state_batch),dim=1)[0] #g)
                        else:
                            maxQ = torch.max(Q(End_state_batch),dim=1)[0] #e=) 3.
                    
                    # action_index = np.stack((np.arange(batch_size),Actions_batch),axis=0)
                    # ids = np.arange(batch_size)
                    
                    Qnow = Q(Start_state_batch)
                    # print(f'{action_index.shape=}')
                    # print(f'{Qnow.shape=}')
                    Qnow = Qnow[np.arange(batch_size), Actions_batch] #Q(x_t,u_t) is given
                    # print(Rewards_batch.shape, maxQ.shape, Terminal_batch.shape, Qnow.shape)
                    Loss = torch.mean((Rewards_batch + gamma*maxQ*(1-Terminal_batch) - Qnow)**2) #e) 3.
                    optimizer.zero_grad() #e) 3.
                    Loss.backward() #e) 3.
                    optimizer.step() #e) 3.
                
            score = np.mean([eval_Q(Q,env) for i in range(N_evals)])
            print(f'iteration={iteration} Average Reward per episode: {score:.2f}')
            if score > best:
                best = score
                print('################################# \n new best',best,'saving Q... \n#################################')
                torch.save(Q.state_dict(),'Q-checkpoint')
            
            print('loading best result')
            Q.load_state_dict(torch.load('Q-checkpoint'))
    finally: #this will always run even when using the a KeyBoard Interrupt. 
        print('loading best result')
        Q.load_state_dict(torch.load('Q-checkpoint'))

# %%
gamma = 0.999 #f=)
batch_size = 64 #f=)
N_iterations = 50 #f=)
N_rollout = 20000 #f=)
N_epochs = 6 #f=)
N_evals = 5 #f=)
lr = 0.005 #given
target_net_update_feq = 200

Q = Qfunction(env)
optimizer = torch.optim.Adam(Q.parameters(),lr=lr) #low learning rate
DQN_rollout(Q, optimizer, env, use_target_net=True, gamma=gamma, N_iterations=N_iterations, \
            N_rollout=N_rollout, N_epochs=N_epochs, N_evals=N_evals, batch_size=batch_size, \
            target_net_update_feq=target_net_update_feq)
# Out:
# rollout iteration 0 with epsilon=100.00%...
# starting training on rollout information...
# iteration=0 Average Reward per episode: 11.08
# #################################
#  new best 11.08399209165278 saving Q...
# #################################
# loading best result
# rollout iteration 1 with epsilon=98.67%...
# starting training on rollout information...
# iteration=1 Average Reward per episode: 212.14
# #################################
#  new best 212.14422961122222 saving Q...
# #################################
# loading best result
# rollout iteration 2 with epsilon=97.33%...
# starting training on rollout information...
# iteration=2 Average Reward per episode: 63.25
# loading best result
# rollout iteration 3 with epsilon=96.00%...
# starting training on rollout information...
# iteration=3 Average Reward per episode: 185.88
# loading best result
# rollout iteration 4 with epsilon=94.67%...
# starting training on rollout information...
# iteration=4 Average Reward per episode: 0.00
# loading best result
# rollout iteration 5 with epsilon=93.33%...
# starting training on rollout information...
# iteration=5 Average Reward per episode: 219.44
# #################################
#  new best 219.43721173969828 saving Q...
# #################################
# loading best result
# rollout iteration 6 with epsilon=92.00%...
# starting training on rollout information...
# iteration=6 Average Reward per episode: 11.38
# loading best result
# rollout iteration 7 with epsilon=90.67%...
# starting training on rollout information...
# iteration=7 Average Reward per episode: 11.38
# loading best result
# rollout iteration 8 with epsilon=89.33%...
# starting training on rollout information...
# iteration=8 Average Reward per episode: 11.39
# loading best result
# rollout iteration 9 with epsilon=88.00%...
# starting training on rollout information...
# iteration=9 Average Reward per episode: 11.39
# loading best result
# rollout iteration 10 with epsilon=86.67%...
# starting training on rollout information...
# iteration=10 Average Reward per episode: 11.38
# loading best result
# rollout iteration 11 with epsilon=85.33%...
# starting training on rollout information...
# iteration=11 Average Reward per episode: 11.38
# loading best result
# rollout iteration 12 with epsilon=84.00%...
# starting training on rollout information...
# iteration=12 Average Reward per episode: 11.39
# loading best result
# rollout iteration 13 with epsilon=82.67%...
# starting training on rollout information...
# iteration=13 Average Reward per episode: 221.29
# #################################
#  new best 221.28667744528224 saving Q...
# #################################
# loading best result
# rollout iteration 14 with epsilon=81.33%...
# starting training on rollout information...
# iteration=14 Average Reward per episode: 231.63
# #################################
#  new best 231.63470900436127 saving Q...
# #################################
# loading best result
# rollout iteration 15 with epsilon=80.00%...
# starting training on rollout information...
# iteration=15 Average Reward per episode: 0.00
# loading best result
# rollout iteration 16 with epsilon=78.67%...
# starting training on rollout information...
# iteration=16 Average Reward per episode: 223.83
# loading best result
# rollout iteration 17 with epsilon=77.33%...
# starting training on rollout information...
# iteration=17 Average Reward per episode: 228.18
# loading best result
# rollout iteration 18 with epsilon=76.00%...
# starting training on rollout information...
# iteration=18 Average Reward per episode: 229.04
# loading best result
# rollout iteration 19 with epsilon=74.67%...
# starting training on rollout information...
# iteration=19 Average Reward per episode: 226.17
# loading best result
# rollout iteration 20 with epsilon=73.33%...
# starting training on rollout information...
# iteration=20 Average Reward per episode: 228.53
# loading best result
# rollout iteration 21 with epsilon=72.00%...
# starting training on rollout information...
# iteration=21 Average Reward per episode: 232.96
# #################################
#  new best 232.95946790641932 saving Q...
# #################################
# loading best result
# rollout iteration 22 with epsilon=70.67%...
# starting training on rollout information...
# iteration=22 Average Reward per episode: 214.64
# loading best result
# rollout iteration 23 with epsilon=69.33%...
# starting training on rollout information...
# iteration=23 Average Reward per episode: 11.39
# loading best result
# rollout iteration 24 with epsilon=68.00%...
# starting training on rollout information...
# iteration=24 Average Reward per episode: 11.37
# loading best result
# rollout iteration 25 with epsilon=66.67%...
# starting training on rollout information...
# iteration=25 Average Reward per episode: 224.67
# loading best result
# rollout iteration 26 with epsilon=65.33%...
# starting training on rollout information...
# iteration=26 Average Reward per episode: 223.44
# loading best result
# rollout iteration 27 with epsilon=64.00%...
# starting training on rollout information...
# iteration=27 Average Reward per episode: 233.78
# #################################
#  new best 233.77755894746952 saving Q...
# #################################
# loading best result
# rollout iteration 28 with epsilon=62.67%...
# starting training on rollout information...
# iteration=28 Average Reward per episode: 490.77
# #################################
#  new best 490.7738603701167 saving Q...
# #################################
# loading best result
# rollout iteration 29 with epsilon=61.33%...
# starting training on rollout information...
# iteration=29 Average Reward per episode: 223.56
# loading best result
# rollout iteration 30 with epsilon=60.00%...
# starting training on rollout information...
# iteration=30 Average Reward per episode: 219.53
# loading best result
# rollout iteration 31 with epsilon=58.67%...
# starting training on rollout information...
# iteration=31 Average Reward per episode: 232.48
# loading best result
# rollout iteration 32 with epsilon=57.33%...
# starting training on rollout information...
# iteration=32 Average Reward per episode: 559.04
# #################################
#  new best 559.0360127229053 saving Q...
# #################################
# loading best result
# rollout iteration 33 with epsilon=56.00%...
# starting training on rollout information...
# iteration=33 Average Reward per episode: 534.69
# loading best result
# rollout iteration 34 with epsilon=54.67%...
# starting training on rollout information...
# iteration=34 Average Reward per episode: 542.66
# loading best result
# rollout iteration 35 with epsilon=53.33%...
# starting training on rollout information...
# iteration=35 Average Reward per episode: 552.28
# loading best result
# rollout iteration 36 with epsilon=52.00%...
# starting training on rollout information...
# iteration=36 Average Reward per episode: 536.71
# loading best result
# rollout iteration 37 with epsilon=50.67%...
# starting training on rollout information...
# iteration=37 Average Reward per episode: 283.23
# loading best result
# rollout iteration 38 with epsilon=49.33%...
# starting training on rollout information...
# iteration=38 Average Reward per episode: 540.45
# loading best result
# rollout iteration 39 with epsilon=48.00%...
# starting training on rollout information...
# iteration=39 Average Reward per episode: 10.24
# loading best result
# rollout iteration 40 with epsilon=46.67%...
# starting training on rollout information...
# iteration=40 Average Reward per episode: 476.99
# loading best result
# rollout iteration 41 with epsilon=45.33%...
# starting training on rollout information...
# iteration=41 Average Reward per episode: 519.74
# loading best result
# rollout iteration 42 with epsilon=44.00%...
# starting training on rollout information...
# iteration=42 Average Reward per episode: 6.95
# loading best result
# rollout iteration 43 with epsilon=42.67%...
# starting training on rollout information...
# iteration=43 Average Reward per episode: 546.82
# loading best result
# rollout iteration 44 with epsilon=41.33%...
# starting training on rollout information...
# iteration=44 Average Reward per episode: 540.11
# loading best result
# rollout iteration 45 with epsilon=40.00%...
# starting training on rollout information...
# iteration=45 Average Reward per episode: 537.29
# loading best result
# rollout iteration 46 with epsilon=38.67%...
# starting training on rollout information...
# iteration=46 Average Reward per episode: 522.39
# loading best result
# rollout iteration 47 with epsilon=37.33%...
# starting training on rollout information...
# iteration=47 Average Reward per episode: 505.64
# loading best result
# rollout iteration 48 with epsilon=36.00%...
# starting training on rollout information...
# iteration=48 Average Reward per episode: 495.95
# loading best result
# rollout iteration 49 with epsilon=34.67%...
# starting training on rollout information...
# iteration=49 Average Reward per episode: 0.00
# loading best result
# loading best result

# %%
Rewards = [eval_Q(Q,env) for i in range(100)]
plt.plot(Rewards,'.')
plt.title(f'mean={np.mean(Rewards)}')
plt.xlabel('instance')
plt.ylabel('Reward per episode')
plt.show()

# %%
# 1. Load the optimal weights from your best training checkpoint
Q.load_state_dict(torch.load('Q-checkpoint'))

# ==========================================================
# FIX: Explicitly inject the missing render metadata attribute for Gymnasium
# ==========================================================
env.metadata = {"render_modes": ["human"]}
# ==========================================================

# 2. Re-verify the visualization routine with scalar stepping
def watch_final_policy(Q, env):
    with torch.no_grad():
        # Setup the Q-value inference lambda function
        Qfun = lambda x: Q(torch.tensor(x[None, :], dtype=torch.float32))[0].numpy() 
        
        try:
            obs, info = env.reset() 
            env.render() # Opens the simulator visual display window
            time.sleep(1) # Brief pause so you can get ready to watch
            
            rewards_accumulator = 0
            while True: 
                # Network predicts the discrete action choice index (0 to 6)
                action_idx = np.argmax(Qfun(obs)) 
                
                # Extract the pure scalar voltage matching your disk environment requirements
                voltage_action = float(discrete_actions[action_idx])
                
                # Step the environment forward using the pure scalar value
                obs_next, reward, terminated, truncated, info = env.step(voltage_action) 
                obs = np.array(obs_next, dtype=np.float32) 
                
                rewards_accumulator += reward
                
                # Match your step time delta (dt=0.025) for a smooth, true-to-life animation speed
                time.sleep(0.025) 
                env.render() 
                
                if terminated or truncated: 
                    print(f"Episode finished! Total accumulated reward: {rewards_accumulator:.2f}")
                    time.sleep(1.0) # Hold the final frame for a second
                    break  
        finally: 
            env.close() # Clean up and close the visualization window safely

# 3. Trigger the animation!
watch_final_policy(Q, env)
# Out:
# Episode finished! Total accumulated reward: 558.93

# %%
Q.load_state_dict(torch.load('Q-checkpoint'))
show(Q, env)

# %%
import gym_unbalanced_disk
import gymnasium
import numpy as np
from matplotlib import pyplot as plt

umax = 3.0
Q.load_state_dict(torch.load('Q-checkpoint'))

env = gym_unbalanced_disk.UnbalancedDisk_exp(umax=umax, dt=0.025)
obs, info = env.reset()
obs = np.array(obs, dtype=np.float32)

rewards_acc = 0
obs_list = []
action_list = []
reward_list = []

obs, info = env.reset()

obs_list = []
action_list = []
reward_list = []

Q.load_state_dict(torch.load('Q-checkpoint'))

# Simulation run
env_sim = gym.make('unbalanced-disk-sincos-v0', dt=0.025, umax=3.)
env_sim = gym.wrappers.TimeLimit(env_sim, max_episode_steps=200)
env_sim.unwrapped.reward_fun = lambda self: 0.5 * (1.0 - np.cos(self.th))

obs, info = env_sim.reset()
obs = np.array(obs, dtype=np.float32)

print("=== SIMULATION ===")
print(f"{'sin':>8} {'cos':>8} {'omega':>8}")
with torch.no_grad():
    Qfun = lambda x: Q(torch.tensor(x[None,:], dtype=torch.float32))[0].numpy()
    for _ in range(200):
        action = np.argmax(Qfun(obs))
        voltage = float(discrete_actions[action])
        obs, reward, terminated, truncated, info = env_sim.step(voltage)
        obs = np.array(obs, dtype=np.float32)
        if obs[1] < -0.9:  # only print when near top
            print(f'{obs[0]:>8.3f} {obs[1]:>8.3f} {obs[2]:>8.3f}')
        if terminated or truncated:
            break
env_sim.close()

# Real hardware run
print("\n=== REAL HARDWARE ===")
print(f"{'sin':>8} {'cos':>8} {'omega':>8}")
env_exp = gym_unbalanced_disk.UnbalancedDisk_exp(umax=3.0, dt=0.025)
obs, info = env_exp.reset()

try:
    with torch.no_grad():
        Qfun = lambda x: Q(torch.tensor(x[None,:], dtype=torch.float32))[0].numpy()
        for _ in range(200):
            th, omega = obs[0], obs[1]
            obs_sincos = np.array([np.sin(th), np.cos(th), omega], dtype=np.float32)
            if obs_sincos[1] < -0.9:  # only print when near top
                print(f'{obs_sincos[0]:>8.3f} {obs_sincos[1]:>8.3f} {obs_sincos[2]:>8.3f}')
            action = np.argmax(Qfun(obs_sincos))
            voltage = float(discrete_actions[action])
            obs, reward, terminated, truncated, info = env_exp.step(voltage)
        print(f'Total reward: {sum(reward_list):.2f}')
finally:
    env_exp.reset()
    env_exp.close()

# Plot results
obs_arr = np.array(obs_list)
t = np.arange(len(obs_arr)) * 0.025

plt.figure(figsize=(10,6))
plt.subplot(3,1,1)
plt.plot(t, np.degrees(np.arctan2(obs_arr[:,0], obs_arr[:,1])))
plt.axhline(180, color='r', ls='--', label='target')
plt.ylabel('θ [deg]'); plt.legend(); plt.grid(True)
plt.subplot(3,1,2)
plt.plot(t, obs_arr[:,2], 'g')
plt.ylabel('ω [rad/s]'); plt.grid(True)
plt.subplot(3,1,3)
plt.plot(t, action_list, 'r')
plt.ylabel('u [V]'); plt.xlabel('time [s]'); plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 9
#       6 umax = 3.0
#       7 Q.load_state_dict(torch.load('Q-checkpoint'))
# ----> 9 env = gym_unbalanced_disk.UnbalancedDisk_exp(umax=umax, dt=0.025)
#      10 obs, info = env.reset()
#      11 obs = np.array(obs, dtype=np.float32)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gym_unbalanced_disk\envs\UnbalancedDiskExp.py:38, in UnbalancedDisk_exp.__init__(self, umax, dt, force_restart_dev, inactivity_release_time, render_mode)
#      36     self.dev = dev
#      37 if not dev_active or force_restart_dev:
# ---> 38     self.init_dev()
#      40 assert isinstance(inactivity_release_time, int)
#      41 self.set_inactivity_release_time(inactivity_release_time)
#
# File ~\anaconda3\envs\ml4sc\Lib\site-packages\gym_unbalanced_disk\envs\UnbalancedDiskExp.py:79, in UnbalancedDisk_exp.init_dev(self)
#      77     pass
#      78 dev = usb.core.find(idVendor=0x04b4, idProduct=0x8612)
# ---> 79 dev.set_configuration() #this throws and error if python cannot connect to the disk.
#      80 self.dev = dev
#      81 dev_active = True
#
# AttributeError: 'NoneType' object has no attribute 'set_configuration'

# %%
env.close()
