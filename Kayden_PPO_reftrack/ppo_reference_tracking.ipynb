# %% [markdown]
# ---
# # RUN ORDER — WHAT TO RUN FOR THE REAL HARDWARE
#
# **REQUIRED, in this order:**
# 1. Cell 1 — install deps
# 2. Cell 2 — imports
# 3. Cell 4 — environment wrapper (defines `ALLOWED_VOLTAGES`, action + reward wrappers)
# 4. Cell 6 — loads/trains `model` (loads `ppo_reftrack.zip` if it exists, otherwise trains for a while)
# 5. **Cell 12 — HARDWARE DEMO.** Disc at bottom, USB connected, run this. Interrupt the kernel to stop.
# 6. Cell 13 — plots `hardware_log.npy` from the run above
#
# **NOT needed for hardware (skip these):**
# - Cells 8, 10 — simulation-only evaluation / plots
# - Cells 14–16 — system-ID sim-vs-hardware diagnostic (separate experiment)
# - Cell 17 — simulation-only test loop (infinite loop, never run on real hardware)
# ---

# %%
import subprocess, sys
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'stable-baselines3', 'matplotlib'])
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip
# 0

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

sys.path.insert(0, os.path.abspath('..'))
import gym_unbalanced_disk
# Out:
# /home/kaydenknapik/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /home/kaydenknapik/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/kaydenknapik/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## Reference-Tracking Environment Wrapper
#
# The base environment has a 3D observation: [sin θ, cos θ, ω].
#
# We extend it to 5D: **[sin θ, cos θ, ω, sin θ_ref, cos θ_ref]**
#
# Using sin/cos for the reference (rather than the raw angle) avoids wrap-around discontinuities and keeps the representation consistent with the state encoding.
#
# Reward: Gaussian centered on the reference angle:
# $$r = \exp\!\left(-\frac{(\angle(\theta - \theta_\mathrm{ref}))^2}{2\sigma^2}\right)$$
# where σ = π/8 ≈ 22.5°. This gives r ≈ 1 when on-target and decays smoothly away.
#
# **Tracking is temporarily disabled** (`REF_RANGE = 0`) to isolate and debug swing-up + hold-at-top robustness on hardware. The reference is fixed at π (top) every episode. Restore `REF_RANGE = np.radians(15)` once hold stability is solid.
#
# **Perturbation training**: on hardware, falling off the top led to several uncontrolled spins before the policy recovered — it had never seen those "mid-tumble" states during training, since every training episode used to start from rest at the bottom. 50% of episodes (`RANDOM_RESET_FRAC`) now start from a random angle and a random angular velocity up to ±20 rad/s (`RANDOM_OMEGA_MAX`, matching the max |ω| ≈ 19.7 rad/s seen in a real hardware run) so the policy practices recovering from a tumble, not just swinging up from a standstill.

# %%
ALLOWED_VOLTAGES = [-3.0, -1.5, -0.5, 0.0, 0.5, 1.5, 3.0]  # bang-bang action set (Q-learning insight)
DT_SIM = 0.034  # matches measured real hardware control-loop time, not the nominal 0.025


class DiscretizeAction(gym.ActionWrapper):
    def __init__(self, env, voltages):
        super().__init__(env)
        self.voltages = np.array(voltages, dtype=np.float32)
        self.action_space = gym.spaces.Discrete(len(self.voltages))

    def action(self, act):
        return float(self.voltages[int(act)])


class UnbalancedDiskRef(gym.Wrapper):
    REF_RANGE  = 0  # tracking disabled for now — focus on robust swing-up + hold at top. Restore to np.radians(15) to re-enable.
    BRAKE_ZONE = np.pi / 4  # only penalise speed within 45 deg of target (Q-learning insight)
    RANDOM_RESET_FRAC = 0.5  # fraction of episodes starting from a random tumbling state instead of bottom-at-rest
    RANDOM_OMEGA_MAX  = 20.0  # rad/s — matches max |omega| ~19.7 observed in a real hardware run

    def __init__(self, env, encoder_error_deg=2.0, dt=DT_SIM):
        super().__init__(env)
        low  = np.concatenate([env.observation_space.low,  [-1., -1.]]).astype(np.float32)
        high = np.concatenate([env.observation_space.high, [ 1.,  1.]]).astype(np.float32)
        self.observation_space = gym.spaces.Box(low=low, high=high, dtype=np.float32)
        self.th_ref = np.pi
        # Physically-derived sensor noise: sigma_omega from numerical-differentiation
        # error propagation of a noisy encoder reading sigma_theta (sqrt(2)/dt scaling).
        self.sigma_th = np.radians(encoder_error_deg)
        self.sigma_om = (np.sqrt(2) / dt) * self.sigma_th

    def _augment(self, raw_obs):
        ref = np.array([np.sin(self.th_ref), np.cos(self.th_ref)], dtype=np.float32)
        th  = np.arctan2(raw_obs[0], raw_obs[1]) + np.random.randn() * self.sigma_th
        om  = raw_obs[2] + np.random.randn() * self.sigma_om
        noisy = np.array([np.sin(th), np.cos(th), om], dtype=np.float32)
        return np.concatenate([noisy, ref])

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        if np.random.rand() < self.RANDOM_RESET_FRAC:
            # perturbation training: start mid-tumble (random angle + speed) so the
            # policy practices recovering after a fall, not just swinging up from rest
            base = self.env.unwrapped
            base.th    = np.random.uniform(-np.pi, np.pi)
            base.omega = np.random.uniform(-self.RANDOM_OMEGA_MAX, self.RANDOM_OMEGA_MAX)
            obs = base.get_obs()
        self.th_ref = np.pi + np.random.uniform(-self.REF_RANGE, self.REF_RANGE)
        return self._augment(obs), info

    def step(self, action):
        obs, _, terminated, truncated, info = self.env.step(action)
        th     = np.arctan2(obs[0], obs[1])
        th_err = ((th - self.th_ref + np.pi) % (2 * np.pi)) - np.pi
        reward = 0.5 * (1.0 + np.cos(th_err))
        if abs(th_err) < self.BRAKE_ZONE:           # Q-learning-style conditional braking penalty
            reward -= 0.005 * obs[2]**2
        return self._augment(obs), float(reward), terminated, truncated, info


def make_env():
    env = gym.make('unbalanced-disk-sincos-v0', dt=DT_SIM)
    env = DiscretizeAction(env, ALLOWED_VOLTAGES)
    return UnbalancedDiskRef(env, dt=DT_SIM)


env = make_env()
print('obs space  :', env.observation_space)
print('action space:', env.action_space)
obs, _ = env.reset()
print('sample obs :', obs)
# Out:
# obs space  : Box([ -1.  -1. -40.  -1.  -1.], [ 1.  1. 40.  1.  1.], (5,), float32)
# action space: Discrete(7)
# sample obs : [-1.4509580e-02  9.9989474e-01  9.5981127e-01  1.2246469e-16
#  -1.0000000e+00]
# /home/kaydenknapik/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /home/kaydenknapik/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %% [markdown]
# ## PPO Training
#
# Same PPO setup as the swing-up (4.2.1) — 4 parallel environments, 300k timesteps.
# The only difference is the 5D observation and the reference-tracking reward.
#
# If a saved model exists it is loaded directly to avoid retraining.

# %%
_nb   = globals().get('__vsc_ipynb_file__', '')
_here = os.path.dirname(os.path.abspath(_nb)) if _nb else os.getcwd()
MODEL_PATH = os.path.join(_here, 'ppo_reftrack.zip')

if os.path.exists(MODEL_PATH):
    model = PPO.load(MODEL_PATH)
    print('Loaded saved model.')
else:
    vec_env = make_vec_env(make_env, n_envs=4)
    model = PPO(
        'MlpPolicy', vec_env,
        learning_rate=3e-4,
        gamma=0.99,
        ent_coef=0.005,
        n_steps=1024,
        batch_size=64,
        verbose=1,
        seed=42,
    )
    model.learn(total_timesteps=300_000)
    model.save(MODEL_PATH)
    print('Training done, model saved.')
# Out:
# Using cpu device
# /home/kaydenknapik/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /home/kaydenknapik/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /home/kaydenknapik/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:134: UserWarning: WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /home/kaydenknapik/.local/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 15.5     |
# | time/              |          |
# |    fps             | 1945     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 1371        |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.028516091 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -0.073      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0738      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 0.547       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 40.4        |
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014455993 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.467       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.578       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 54         |
# | time/                   |            |
# |    fps                  | 1276       |
# |    iterations           | 4          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01373891 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.476      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.21       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0261    |
# |    value_loss           | 4.7        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 67.3        |
# | time/                   |             |
# |    fps                  | 1254        |
# |    iterations           | 5           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012873234 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 6.2         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 76.3         |
# | time/                   |              |
# |    fps                  | 1245         |
# |    iterations           | 6            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0073078256 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.165        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.22         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 5.68         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 80.7       |
# | time/                   |            |
# |    fps                  | 1240       |
# |    iterations           | 7          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01272958 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.7       |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.48       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0174    |
# |    value_loss           | 4.22       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 93.4        |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011314455 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.00472    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 5.03        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 1212         |
# |    iterations           | 9            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0070000365 |
# |    clip_fraction        | 0.0841       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.75         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00853     |
# |    value_loss           | 3.4          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 1210        |
# |    iterations           | 10          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008894177 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 3.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 1206        |
# |    iterations           | 11          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009883979 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 2.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 12          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013190044 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.528       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 2.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 140         |
# | time/                   |             |
# |    fps                  | 1191        |
# |    iterations           | 13          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010029316 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.767       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 1.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 1187        |
# |    iterations           | 14          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010862025 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.296       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.938       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 1180        |
# |    iterations           | 15          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009193152 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.75        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00935    |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 16          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010511104 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.402       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.736       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 1.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 166         |
# | time/                   |             |
# |    fps                  | 1166        |
# |    iterations           | 17          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012691273 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.532       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 1.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 172         |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 18          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010144379 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.905       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 1.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 178         |
# | time/                   |             |
# |    fps                  | 1150        |
# |    iterations           | 19          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009551166 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.767       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 1.95        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 186         |
# | time/                   |             |
# |    fps                  | 1143        |
# |    iterations           | 20          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010224411 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.919       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 2.14        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 191         |
# | time/                   |             |
# |    fps                  | 1130        |
# |    iterations           | 21          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008733997 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 198         |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 22          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009163528 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 2.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 204         |
# | time/                   |             |
# |    fps                  | 1110        |
# |    iterations           | 23          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008418269 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.536       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.008      |
# |    value_loss           | 2.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 1095        |
# |    iterations           | 24          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009423217 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.53        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00818    |
# |    value_loss           | 3           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 25          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008561095 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.547       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 26          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008206655 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | 0.593       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 2.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 231         |
# | time/                   |             |
# |    fps                  | 1021        |
# |    iterations           | 27          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.005375092 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.883      |
# |    explained_variance   | 0.595       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 3.02        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 1011         |
# |    iterations           | 28           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0054787416 |
# |    clip_fraction        | 0.0586       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.955        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00451     |
# |    value_loss           | 3.25         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 240         |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 29          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005236023 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.933      |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 3.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 245         |
# | time/                   |             |
# |    fps                  | 981         |
# |    iterations           | 30          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.007980408 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 31          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.006177228 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.884      |
# |    explained_variance   | 0.677       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 2.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 32          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.005655366 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.19        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 33          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 135168      |
# | train/                  |             |
# |    approx_kl            | 0.009830965 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.76        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 2.45        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 34           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0043018083 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.823       |
# |    explained_variance   | 0.658        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.707        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 2.64         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 947         |
# |    iterations           | 35          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 143360      |
# | train/                  |             |
# |    approx_kl            | 0.006293265 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.7         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 2.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 260         |
# | time/                   |             |
# |    fps                  | 939         |
# |    iterations           | 36          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.008318678 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 2.81        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 262          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 37           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0077019483 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.971        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00424     |
# |    value_loss           | 1.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 38           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 155648       |
# | train/                  |              |
# |    approx_kl            | 0.0063648634 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.548        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 2.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 39          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.005538375 |
# |    clip_fraction        | 0.0639      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.796      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.826       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 1.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 903         |
# |    iterations           | 40          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.008364733 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.783      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.655       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00217    |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 900         |
# |    iterations           | 41          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.005228204 |
# |    clip_fraction        | 0.0528      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.388       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 1.51        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 270          |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 42           |
# |    time_elapsed         | 191          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0070172427 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.648        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 1.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 893          |
# |    iterations           | 43           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0127603905 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.774       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.8          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 1.22         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 271         |
# | time/                   |             |
# |    fps                  | 882         |
# |    iterations           | 44          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.007352616 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.721      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.718       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 1.58        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 880         |
# |    iterations           | 45          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006950696 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.492       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 1.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 46          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.005407742 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.686       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.732       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 1.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 47          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.009195306 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.812      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.37        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 0.995       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 48          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008438186 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.212       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 1.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 49          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.007955622 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.601       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 0.975       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 50          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.008633049 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 1.17        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 274          |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 51           |
# |    time_elapsed         | 244          |
# |    total_timesteps      | 208896       |
# | train/                  |              |
# |    approx_kl            | 0.0056808065 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.817       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.702        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 1.15         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 52           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0068916674 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.537        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 1.35         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 53          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 217088      |
# | train/                  |             |
# |    approx_kl            | 0.010165469 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.409       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 1.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 54          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.007915543 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 57          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 233472      |
# | train/                  |             |
# |    approx_kl            | 0.007102647 |
# |    clip_fraction        | 0.085       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 0.932       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 277        |
# | time/                   |            |
# |    fps                  | 840        |
# |    iterations           | 58         |
# |    time_elapsed         | 282        |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.00783941 |
# |    clip_fraction        | 0.0847     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.791     |
# |    explained_variance   | 0.704      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.705      |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.00277   |
# |    value_loss           | 1.5        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 839          |
# |    iterations           | 59           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 241664       |
# | train/                  |              |
# |    approx_kl            | 0.0071761347 |
# |    clip_fraction        | 0.0794       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.302        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000708    |
# |    value_loss           | 0.7          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 835          |
# |    iterations           | 60           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0062313946 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.611        |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 1.12         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 833          |
# |    iterations           | 61           |
# |    time_elapsed         | 299          |
# |    total_timesteps      | 249856       |
# | train/                  |              |
# |    approx_kl            | 0.0061747963 |
# |    clip_fraction        | 0.0914       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.386        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 0.697        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 62           |
# |    time_elapsed         | 305          |
# |    total_timesteps      | 253952       |
# | train/                  |              |
# |    approx_kl            | 0.0051118373 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.587        |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00385     |
# |    value_loss           | 1.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 63           |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 258048       |
# | train/                  |              |
# |    approx_kl            | 0.0076798256 |
# |    clip_fraction        | 0.0944       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.761       |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.682        |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 0.657        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 300        |
# |    ep_rew_mean          | 277        |
# | time/                   |            |
# |    fps                  | 831        |
# |    iterations           | 64         |
# |    time_elapsed         | 315        |
# |    total_timesteps      | 262144     |
# | train/                  |            |
# |    approx_kl            | 0.01254488 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.821     |
# |    explained_variance   | 0.856      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.142      |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.00213   |
# |    value_loss           | 0.427      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 65           |
# |    time_elapsed         | 320          |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0075674905 |
# |    clip_fraction        | 0.0877       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.134        |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 0.587        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 829         |
# |    iterations           | 66          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.009296613 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 0.278       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 826          |
# |    iterations           | 67           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0070298817 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.742        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0588       |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.0041      |
# |    value_loss           | 0.91         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 68          |
# |    time_elapsed         | 337         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.007251299 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.577       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 69          |
# |    time_elapsed         | 343         |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.008346417 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04        |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 2.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 70          |
# |    time_elapsed         | 349         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.004876674 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.733      |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.922       |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 2.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 71          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.008677359 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.995       |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 2           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 72          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.013924321 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.207       |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.00323    |
# |    value_loss           | 0.801       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 73          |
# |    time_elapsed         | 365         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.010884854 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.797      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 0.331       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 74           |
# |    time_elapsed         | 370          |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0051445086 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.331        |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 0.618        |
# ------------------------------------------
# Training done, model saved.

# %% [markdown]
# ## Evaluation Across Reference Angles
#
# Test the trained policy at several fixed reference angles: -15°, 0°, and +15° around the top.

# %%
def run_episode(ref_deg, n_episodes=5):
    th_ref = np.pi + np.radians(ref_deg)
    rewards = []
    for _ in range(n_episodes):
        env_e = make_env()
        obs, _ = env_e.reset()
        env_e.th_ref = th_ref
        obs[-2] = np.sin(th_ref)
        obs[-1] = np.cos(th_ref)
        total = 0.0
        done = False
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, r, terminated, truncated, _ = env_e.step(action)
            total += r
            done = terminated or truncated
        rewards.append(total)
    return np.mean(rewards)

RUN_EVAL = False  # set to True to run simulation evaluation

if RUN_EVAL:
    for deg in [-15, -10, -5, 0, 5, 10, 15]:
        score = run_episode(deg)
        print(f'  ref = {deg:+3d}°  →  mean reward = {score:.1f} / 300')

# %% [markdown]
# ## Episode Plots at Three Reference Angles

# %%
def plot_episode(ref_deg):
    th_ref = np.pi + np.radians(ref_deg)
    env_e = make_env()
    obs, _ = env_e.reset()
    env_e.th_ref = th_ref
    obs[-2] = np.sin(th_ref)
    obs[-1] = np.cos(th_ref)

    obs_list, act_list, rew_list = [], [], []
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs_list.append(obs.copy())
        act_list.append(float(ALLOWED_VOLTAGES[int(action)]))
        obs, r, terminated, truncated, _ = env_e.step(action)
        rew_list.append(r)
        done = terminated or truncated

    obs_arr = np.array(obs_list)
    th_arr  = np.degrees(np.arctan2(obs_arr[:, 0], obs_arr[:, 1]))
    t       = np.arange(len(th_arr)) * DT_SIM

    fig, axes = plt.subplots(3, 1, figsize=(9, 6), sharex=True)
    axes[0].plot(t, th_arr, label='θ')
    axes[0].axhline(180 + ref_deg, color='r', ls='--', label=f'ref ({180+ref_deg}°)')
    axes[0].set_ylabel('θ [deg]'); axes[0].legend(); axes[0].grid(True)
    axes[1].plot(t, obs_arr[:, 2], 'g')
    axes[1].set_ylabel('ω [rad/s]'); axes[1].grid(True)
    axes[2].plot(t, act_list, 'r')
    axes[2].set_ylabel('u [V]'); axes[2].set_xlabel('time [s]'); axes[2].grid(True)
    plt.suptitle(f'PPO reference tracking — ref = {180+ref_deg}°')
    plt.tight_layout()
    plt.show()
    print(f'Total reward: {sum(rew_list):.1f} / {len(rew_list)}')

if RUN_EVAL:
    for deg in [-15, 0, 15]:
        plot_episode(deg)

# %% [markdown]
# ## >>> RUN THIS CELL FOR THE REAL HARDWARE <<<
#
# **Required first:** cells 1, 2, 4, 6 must already have been run (installs, imports, wrapper, `model`).
#
# Make sure the disc is at the **bottom position** before running. Connects over USB, swings up to 180° and holds there (tracking is temporarily disabled — see cell 4). Interrupt the kernel to stop.

# %%
import time
import pygame

env_live = gym_unbalanced_disk.UnbalancedDisk_exp_sincos()
obs, _ = env_live.reset()

def make_obs(raw_obs, th_ref):
    ref = np.array([np.sin(th_ref), np.cos(th_ref)], dtype=np.float32)
    return np.concatenate([np.asarray(raw_obs, dtype=np.float32), ref])

def draw_overlay(env, phase, th_ref, th):
    if not hasattr(env, '_font'):
        pygame.font.init()
        env._font = pygame.font.SysFont('monospace', 18, bold=True)
    lines = [
        f'Phase:  {phase}',
        f'Target: {np.degrees(th_ref) % 360:.1f} deg',
        f'Angle:  {np.degrees(th) % 360 if abs(np.degrees(th) % 360 - 360) > 0.5 else 0.0:.1f} deg',
    ]
    for i, line in enumerate(lines):
        surf = env._font.render(line, True, (30, 30, 30))
        env.viewer.blit(surf, (10, 10 + i * 22))
    pygame.display.flip()

RENDER_EVERY = 0  # 0 = no render on hardware (keeps control loop at ~25ms)

phase       = 'swing-up'
phase_start = time.time()
th_ref      = np.pi  # tracking disabled — fixed target at the top
log    = []
t_last = time.time()
step   = 0

print('Phase: swing-up (target = 180°)')
try:
    while True:
        t_now     = time.time()
        actual_dt = t_now - t_last
        t_last    = t_now
        th        = np.arctan2(obs[0], obs[1])
        near_top  = abs((th - np.pi + np.pi) % (2*np.pi) - np.pi) < np.radians(25)

        if phase == 'swing-up' and near_top:
            phase, phase_start = 'holding', t_now
            print('Phase: holding at 180°...')

        action, _ = model.predict(make_obs(obs, th_ref), deterministic=True)
        u_applied = ALLOWED_VOLTAGES[int(action)]
        log.append([t_now, np.degrees(th) % 360 if abs(np.degrees(th) % 360 - 360) > 0.5 else 0.0, float(obs[2]), u_applied, actual_dt, np.degrees(th_ref) % 360])

        obs, _, terminated, truncated, _ = env_live.step(u_applied)
        step += 1

        if RENDER_EVERY > 0 and step % RENDER_EVERY == 0:
            env_live.render()
            draw_overlay(env_live, phase, th_ref, th)

        if terminated or truncated:
            print('Episode ended, restarting...')
            obs, _ = env_live.reset()
            phase, phase_start = 'swing-up', time.time()
            t_last = time.time()
            step   = 0
            print('Phase: swing-up (target = 180°)')
finally:
    env_live.close()
    if log:
        log_arr = np.array(log)
        np.save('hardware_log.npy', log_arr)
        print(f'\nLog saved ({len(log)} steps)')
        print(f'Mean dt: {log_arr[:,4].mean()*1000:.1f}ms  (target: 25ms)')
        print(f'Omega std: {log_arr[:,2].std():.3f} rad/s')
        print(f'Max |omega|: {np.abs(log_arr[:,2]).max():.1f} rad/s')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 import time
#       2 import pygame
# ----> 4 env_live = gym_unbalanced_disk.UnbalancedDisk_exp_sincos()
#       5 obs, _ = env_live.reset()
#       7 def make_obs(raw_obs, th_ref):
#
# File ~/gym-unbalanced-disk/gym_unbalanced_disk/envs/UnbalancedDiskExp.py:257, in UnbalancedDisk_exp_sincos.__init__(self, umax, dt)
#     256 def __init__(self, umax=3., dt = 0.025):
# --> 257     super(UnbalancedDisk_exp_sincos, self).__init__(umax=umax, dt=dt)
#     258     low = [-1,-1,-40.]
#     259     high = [1,1,40.]
#
# File ~/gym-unbalanced-disk/gym_unbalanced_disk/envs/UnbalancedDiskExp.py:38, in UnbalancedDisk_exp.__init__(self, umax, dt, force_restart_dev, inactivity_release_time, render_mode)
#      36     self.dev = dev
#      37 if not dev_active or force_restart_dev:
# ---> 38     self.init_dev()
#      40 assert isinstance(inactivity_release_time, int)
#      41 self.set_inactivity_release_time(inactivity_release_time)
#
# File ~/gym-unbalanced-disk/gym_unbalanced_disk/envs/UnbalancedDiskExp.py:79, in UnbalancedDisk_exp.init_dev(self)
#      77     pass
#      78 dev = usb.core.find(idVendor=0x04b4, idProduct=0x8612)
# ---> 79 dev.set_configuration() #this throws and error if python cannot connect to the disk.
#      80 self.dev = dev
#      81 dev_active = True
#
# AttributeError: 'NoneType' object has no attribute 'set_configuration'

# %%
## Plot hardware log: angle vs target over time
if os.path.exists('hardware_log.npy'):
    hw = np.load('hardware_log.npy')
    # columns: t, theta_deg, omega, action, dt, th_ref_deg
    t       = hw[:, 0] - hw[0, 0]
    th_deg  = hw[:, 1]
    th_ref_deg = hw[:, 5] if hw.shape[1] > 5 else np.full(len(t), 180.0)

    fig, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)

    axes[0].plot(t, th_deg,     label='θ (actual)',  color='steelblue')
    axes[0].plot(t, th_ref_deg, label='θ_ref (target)', color='crimson', linestyle='--', linewidth=1.5)
    axes[0].set_ylabel('Angle (deg)')
    axes[0].legend(); axes[0].grid(True)
    axes[0].set_title('Hardware run: angle tracking')

    axes[1].plot(t, hw[:, 2], color='darkorange', label='ω (rad/s)')
    axes[1].axhline(0, color='k', linewidth=0.5)
    axes[1].set_ylabel('ω (rad/s)'); axes[1].legend(); axes[1].grid(True)

    axes[2].plot(t, hw[:, 3], color='green', label='action (V)')
    axes[2].set_ylabel('Action (V)'); axes[2].set_xlabel('Time (s)')
    axes[2].legend(); axes[2].grid(True)

    plt.tight_layout()
    plt.savefig('hardware_log_plot.png', dpi=120)
    plt.show()
    print(f'Steps: {len(t)}  Duration: {t[-1]:.1f}s  Mean dt: {hw[:,4].mean()*1000:.1f}ms')
else:
    print('No hardware_log.npy found — run the hardware cell first.')

# %%
## System ID: record sim trajectory (policy actions + resulting states)
env_id  = make_env()
obs, _  = env_id.reset()
sim_rec = []  # [step_t, theta_deg, omega, action]

for step in range(300):
    action, _ = model.predict(obs, deterministic=True)
    u_applied = ALLOWED_VOLTAGES[int(action)]
    th = np.arctan2(obs[0], obs[1])
    sim_rec.append([step * env_id.unwrapped.dt, np.degrees(th) % 360, float(obs[2]), u_applied])
    obs, _, term, trunc, _ = env_id.step(action)
    if term or trunc:
        break

env_id.close()
sim_rec = np.array(sim_rec)
np.save('sysid_sim.npy', sim_rec)
print(f'Sim: {len(sim_rec)} steps, max|omega|={np.abs(sim_rec[:,2]).max():.1f}, final theta={sim_rec[-1,1]:.1f} deg')

# %%
## System ID: play sim actions open-loop on hardware, record response
import time
sim_rec = np.load('sysid_sim.npy')

env_hw = gym_unbalanced_disk.UnbalancedDisk_exp_sincos()
obs, _ = env_hw.reset()
hw_rec = []  # [actual_t, theta_deg, omega, action]
t0 = time.time()

for i, row in enumerate(sim_rec):
    action = np.array([row[3]], dtype=np.float32)
    th = np.arctan2(obs[0], obs[1])
    hw_rec.append([time.time() - t0, np.degrees(th) % 360, float(obs[2]), float(row[3])])
    obs, _, _, _, _ = env_hw.step(action)

env_hw.close()
hw_rec = np.array(hw_rec)
np.save('sysid_hw.npy', hw_rec)
print(f'Hardware: {len(hw_rec)} steps, actual duration={hw_rec[-1,0]:.2f}s (sim expected {sim_rec[-1,0]:.2f}s)')
print(f'Mean dt: {np.diff(hw_rec[:,0]).mean()*1000:.1f}ms  (sim: {sim_rec[1,0]*1000:.1f}ms)')

# %%
## System ID: compare sim vs hardware response to identical actions
sim_rec = np.load('sysid_sim.npy')
hw_rec  = np.load('sysid_hw.npy')

fig, axes = plt.subplots(3, 1, figsize=(13, 9), sharex=False)

# Plot vs step number to remove timing difference — shows pure dynamics mismatch
steps = np.arange(min(len(sim_rec), len(hw_rec)))
n = len(steps)

axes[0].plot(steps, sim_rec[:n, 1], label='Sim θ', color='steelblue')
axes[0].plot(steps, hw_rec[:n,  1], label='HW θ',  color='crimson', linestyle='--')
axes[0].set_ylabel('Angle (deg)'); axes[0].legend(); axes[0].grid(True)
axes[0].set_title('Same actions, step-aligned — difference = dynamics mismatch')

axes[1].plot(steps, sim_rec[:n, 2], label='Sim ω', color='steelblue')
axes[1].plot(steps, hw_rec[:n,  2], label='HW ω',  color='crimson', linestyle='--')
axes[1].set_ylabel('ω (rad/s)'); axes[1].legend(); axes[1].grid(True)

axes[2].plot(steps, sim_rec[:n, 3], label='Action (V)', color='green')
axes[2].set_ylabel('Action (V)'); axes[2].set_xlabel('Step')
axes[2].legend(); axes[2].grid(True)

plt.tight_layout()
plt.savefig('sysid_comparison.png', dpi=120)
plt.show()

# Timing comparison
print(f'Sim step:      {sim_rec[1,0]*1000:.1f}ms')
print(f'HW mean step:  {np.diff(hw_rec[:,0]).mean()*1000:.1f}ms')
print(f'Timing ratio:  {np.diff(hw_rec[:,0]).mean() / sim_rec[1,0]:.3f}x (ideal=1.0)')

# %%
## Simulation test with obs vs target logging
import time

def make_obs(raw_obs, th_ref):
    ref = np.array([np.sin(th_ref), np.cos(th_ref)], dtype=np.float32)
    return np.concatenate([np.asarray(raw_obs, dtype=np.float32), ref])

env_sim = gym_unbalanced_disk.UnbalancedDisk_sincos(dt=DT_SIM)
obs, _  = env_sim.reset()
phase, phase_start = 'swing-up', time.time()
th_ref = np.pi  # tracking disabled — fixed target at the top
sim_log = []

try:
    while True:
        t_now    = time.time()
        th       = np.arctan2(obs[0], obs[1])
        near_top = abs((th - np.pi + np.pi) % (2*np.pi) - np.pi) < np.radians(25)
        if phase == 'swing-up' and near_top:
            phase, phase_start = 'holding', t_now
        action, _ = model.predict(make_obs(obs, th_ref), deterministic=True)
        u_applied = ALLOWED_VOLTAGES[int(action)]
        sim_log.append([t_now, np.degrees(th) % 360 if abs(np.degrees(th) % 360 - 360) > 0.5 else 0.0, float(obs[2]), u_applied, np.degrees(th_ref) % 360])
        obs, _, terminated, truncated, _ = env_sim.step(u_applied)
        env_sim.render()
        time.sleep(env_sim.unwrapped.dt)
        if terminated or truncated:
            obs, _ = env_sim.reset()
            phase, phase_start = 'swing-up', time.time()
finally:
    env_sim.close()
    if sim_log:
        sl = np.array(sim_log)
        t  = sl[:, 0] - sl[0, 0]
        fig, axes = plt.subplots(3, 1, figsize=(12, 8), sharex=True)
        axes[0].plot(t, sl[:, 1], label='θ (actual)',      color='steelblue')
        axes[0].plot(t, sl[:, 4], label='θ_ref (target)',  color='crimson', linestyle='--', linewidth=1.5)
        axes[0].set_ylabel('Angle (deg)'); axes[0].legend(); axes[0].grid(True)
        axes[0].set_title('Simulation: angle tracking')
        axes[1].plot(t, sl[:, 2], color='darkorange', label='ω (rad/s)')
        axes[1].axhline(0, color='k', linewidth=0.5)
        axes[1].set_ylabel('ω (rad/s)'); axes[1].legend(); axes[1].grid(True)
        axes[2].plot(t, sl[:, 3], color='green', label='action (V)')
        axes[2].set_ylabel('Action (V)'); axes[2].set_xlabel('Time (s)')
        axes[2].legend(); axes[2].grid(True)
        plt.tight_layout()
        plt.savefig('sim_log_plot.png', dpi=120)
        plt.show()
